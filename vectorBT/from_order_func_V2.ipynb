# %%
import pandas as pd
import numpy as np
import vectorbt as vbt
from datetime import datetime
import os

# %%
# Prepare data
start = '2019-01-01 UTC'  # crypto is in UTC
end = datetime.utcnow()
dir_name = '/Users/andre/Documents/Python/trading_clone_singapore_DO/trading_singapore_digitalocean/vectorBT'
os.makedirs(dir_name, exist_ok=True)
file_name = 'btc_price_1d.pkl'
joined = os.path.join(dir_name, file_name)

if os.path.exists(joined):
    btc_price = pd.read_pickle(joined)
    print('File exitst already')
else:
    btc_price = vbt.CCXTData.download(exchange = 'kucoin',symbols = 'BTC/USDT',timeframe='1d', start=start, end=end).get()
    btc_price.to_pickle(joined)
    print(btc_price)
    
btc_price.head()

# eth_price = vbt.YFData.download('ETH-USD', start=start, end=end).get('Close')
# comb_price = btc_price.vbt.concat(eth_price,
#     keys=pd.Index(['BTC', 'ETH'], name='symbol'))
# comb_price.vbt.drop_levels(-1, inplace=True)
# comb_price
# Out:
# File exitst already
#                                   Open         High          Low        Close  \
# Open time
# 2019-01-01 00:00:00+00:00  3700.170853  3805.841739  3645.525763  3799.644687
# 2019-01-02 00:00:00+00:00  3799.644687  3880.257733  3750.000001  3856.504318
# 2019-01-03 00:00:00+00:00  3857.633097  3862.600830  3728.917225  3765.999334
# 2019-01-04 00:00:00+00:00  3767.854300  3821.195343  3706.000000  3791.461260
# 2019-01-05 00:00:00+00:00  3789.000000  3838.674540  3756.410862  3772.156039
#
#                                Volume
# Open time
# 2019-01-01 00:00:00+00:00   97.900396
# 2019-01-02 00:00:00+00:00  159.232564
# 2019-01-03 00:00:00+00:00  110.163702
# 2019-01-04 00:00:00+00:00   92.251254
# 2019-01-05 00:00:00+00:00   93.872993

# %% [markdown]
# # first succesful try

# %%
import numpy as np
import pandas as pd
import vectorbt as vbt
from numba import njit
from vectorbt.portfolio.enums import Direction, SizeType

# Create sample price data
btc_price2 = btc_price.head(100).copy()
close_price = btc_price2['Close']


# Define order size (could be a strategy-specific calculation)
# Assume btc_price['Close'], btc_price['High'], btc_price['Low'], and btc_price['Open'] are Series
close = btc_price['Close'].to_numpy()
high = btc_price['High'].to_numpy()
low = btc_price['Low'].to_numpy()
open_ = btc_price['Open'].to_numpy()
btc_price2 = btc_price.to_numpy()

# Numba-compiled order function
@njit
def order_func_nb(c,high,low,open_):

    close_price = c.close[c.i, c.col]
    print("INDEX",c.i)
    print("COL",c.col)
    print("high",high[c.i])
    print('open',open_[c.i])
    print("clsoe",close_price)
    print('low',low[c.i])
    
    #print("lAST_OIDX",c.last_oidx)
    #print("position_record",c.pos_record_now)
    print('position size :',c.position_now)
    if c.position_now > 0:
        print("POSITION IS LONG")
        sl_price = c.pos_record_now[4]* 0.95
        tp_price = c.pos_record_now[4] * 1.05
    print("TP_PRICE",tp_price)
    print("SL_PRICE",sl_price)    
    print()

    
    if (c.position_now == 0) & (c.i != 0) :
        return vbt.portfolio.nb.order_nb(
            size=1.0,  # Fixed size of 1 share/contract
            price=close_price,  # Current closing price
            size_type=SizeType.Amount,  # Specify size type
            direction=Direction.Both  # Long-only trading
        )
    elif (c.position_now > 0) & (sl_price > low[c.i]):
            value = vbt.portfolio.nb.order_nb(
            size=-1,  # Close position
            price=sl_price,
            size_type=SizeType.Amount,
            direction=Direction.LongOnly)  # Long-only trading
            sl_price = 0
            print('stoploss hit')
            print("return value ",value)
            print()

            return value
    elif (c.position_now > 0) & (tp_price < high[c.i]):
            value = vbt.portfolio.nb.order_nb(
            size=-1,  # Close position
            price=tp_price,
            size_type=SizeType.Amount,
            direction=Direction.LongOnly)

            print('tp hit')
            print("return value ",value)
            print()
            return value


    
    return vbt.portfolio.enums.NoOrder

        

# Create portfolio
pf = vbt.Portfolio.from_order_func(
    close_price,           # Price DataFrame
    order_func_nb,
    high,
    low,
    open_,    # Order function
    init_cash=10000  # Initial cash balance
)

# Display some portfolio performance metrics
print("Total Return:", pf.total_return())
print("\nOrder Records:")

pf.orders.records_readable
# Optional: Plot equity curve
pf.plot().show()
# Out:
# INDEX 0
# COL 0
# high 3805.841739
# open 3700.170853
# clsoe 3799.644687
# low 3645.525763
# position size : 0.0
# TP_PRICE 0.0
# SL_PRICE 0.0
#
# INDEX 1
# COL 0
# high 3880.257733
# open 3799.644687
# clsoe 3856.504318
# low 3750.000001
# position size : 0.0
# TP_PRICE 0.0
# SL_PRICE 0.0
#
# INDEX 2
# COL 0
# high 3862.60083
# open 3857.633097
# clsoe 3765.999334
# low 3728.917225
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 4049.3295339
# SL_PRICE 3663.6791020999995
#
# INDEX 3
# COL 0
# high 3821.195343
# open 3767.8543
# clsoe 3791.46126
# low 3706.0
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 4049.3295339
# SL_PRICE 3663.6791020999995
#
# INDEX 4
# COL 0
# high 3838.67454
# open 3789.0
# clsoe 3772.156039
# low 3756.410862
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 4049.3295339
# SL_PRICE 3663.6791020999995
#
# INDEX 5
# COL 0
# high 4023.0
# open 3775.703265
# clsoe 3988.471816
# low 3746.584563
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 4049.3295339
# SL_PRICE 3663.6791020999995
#
# INDEX 6
# COL 0
# high 4017.71888
# open 3984.865903
# clsoe 3972.264189
# low 3927.799365
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 4049.3295339
# SL_PRICE 3663.6791020999995
#
# INDEX 7
# COL 0
# high 4061.280555
# open 3977.721738
# clsoe 3956.635321
# low 3925.0
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 4049.3295339
# SL_PRICE 3663.6791020999995
#
# tp hit
# return value  Order(size=-1.0, price=4049.3295339, size_type=0, direction=0, fees=0.0, fixed_fees=0.0, slippage=0.0, min_size=0.0, max_size=inf, size_granularity=nan, reject_prob=0.0, lock_cash=False, allow_partial=True, raise_reject=False, log=False)
#
# INDEX 8
# COL 0
# high 3999.999999
# open 3953.740659
# clsoe 3967.16117
# low 3940.0
# position size : 0.0
# TP_PRICE 0.0
# SL_PRICE 0.0
#
# INDEX 9
# COL 0
# high 3995.174297
# open 3962.210833
# clsoe 3582.995912
# low 3538.410921
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 4165.5192285
# SL_PRICE 3768.8031115
#
# stoploss hit
# return value  Order(size=-1.0, price=3768.8031115, size_type=0, direction=0, fees=0.0, fixed_fees=0.0, slippage=0.0, min_size=0.0, max_size=inf, size_granularity=nan, reject_prob=0.0, lock_cash=False, allow_partial=True, raise_reject=False, log=False)
#
# INDEX 10
# COL 0
# high 3647.694494
# open 3582.670179
# clsoe 3601.765191
# low 3532.298156
# position size : 0.0
# TP_PRICE 0.0
# SL_PRICE 0.0
#
# INDEX 11
# COL 0
# high 3615.341123
# open 3601.765191
# clsoe 3588.336328
# low 3536.275592
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3781.85345055
# SL_PRICE 3421.6769314499998
#
# INDEX 12
# COL 0
# high 3620.330298
# open 3586.944215
# clsoe 3470.442417
# low 3446.953248
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3781.85345055
# SL_PRICE 3421.6769314499998
#
# INDEX 13
# COL 0
# high 3668.902955
# open 3477.754986
# clsoe 3625.940976
# low 3465.964471
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3781.85345055
# SL_PRICE 3421.6769314499998
#
# INDEX 14
# COL 0
# high 3644.873222
# open 3621.054803
# clsoe 3558.825309
# low 3523.408177
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3781.85345055
# SL_PRICE 3421.6769314499998
#
# INDEX 15
# COL 0
# high 3637.545485
# open 3553.0
# clsoe 3585.539637
# low 3544.18794
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3781.85345055
# SL_PRICE 3421.6769314499998
#
# INDEX 16
# COL 0
# high 3629.854475
# open 3590.559117
# clsoe 3613.059078
# low 3536.929827
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3781.85345055
# SL_PRICE 3421.6769314499998
#
# INDEX 17
# COL 0
# high 3621.231797
# open 3621.231797
# clsoe 3598.563462
# low 3569.950664
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3781.85345055
# SL_PRICE 3421.6769314499998
#
# INDEX 18
# COL 0
# high 3713.263735
# open 3606.551267
# clsoe 3669.514623
# low 3592.39684
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3781.85345055
# SL_PRICE 3421.6769314499998
#
# INDEX 19
# COL 0
# high 3694.320724
# open 3666.0
# clsoe 3541.961501
# low 3482.0
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3781.85345055
# SL_PRICE 3421.6769314499998
#
# INDEX 20
# COL 0
# high 3556.419913
# open 3540.956207
# clsoe 3528.160647
# low 3491.426433
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3781.85345055
# SL_PRICE 3421.6769314499998
#
# INDEX 21
# COL 0
# high 3602.428923
# open 3525.618845
# clsoe 3573.882315
# low 3448.0
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3781.85345055
# SL_PRICE 3421.6769314499998
#
# INDEX 22
# COL 0
# high 3605.0
# open 3570.777944
# clsoe 3553.668236
# low 3516.745198
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3781.85345055
# SL_PRICE 3421.6769314499998
#
# INDEX 23
# COL 0
# high 3585.98651
# open 3548.001237
# clsoe 3565.610748
# low 3526.756089
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3781.85345055
# SL_PRICE 3421.6769314499998
#
# INDEX 24
# COL 0
# high 3577.898931
# open 3567.534218
# clsoe 3571.590258
# low 3520.682464
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3781.85345055
# SL_PRICE 3421.6769314499998
#
# INDEX 25
# COL 0
# high 3653.931361
# open 3566.918941
# clsoe 3564.413089
# low 3549.796545
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3781.85345055
# SL_PRICE 3421.6769314499998
#
# INDEX 26
# COL 0
# high 3581.399326
# open 3564.41309
# clsoe 3556.026201
# low 3500.496895
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3781.85345055
# SL_PRICE 3421.6769314499998
#
# INDEX 27
# COL 0
# high 3559.997922
# open 3548.928346
# clsoe 3439.084664
# low 3385.98654
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3781.85345055
# SL_PRICE 3421.6769314499998
#
# stoploss hit
# return value  Order(size=-1.0, price=3421.6769314499998, size_type=0, direction=0, fees=0.0, fixed_fees=0.0, slippage=0.0, min_size=0.0, max_size=inf, size_granularity=nan, reject_prob=0.0, lock_cash=False, allow_partial=True, raise_reject=False, log=False)
#
# INDEX 28
# COL 0
# high 3445.666304
# open 3432.386812
# clsoe 3416.423082
# low 3352.150773
# position size : 0.0
# TP_PRICE 0.0
# SL_PRICE 0.0
#
# INDEX 29
# COL 0
# high 3479.461934
# open 3407.693594
# clsoe 3465.360373
# low 3380.00245
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3587.2442361
# SL_PRICE 3245.6019278999997
#
# INDEX 30
# COL 0
# high 3494.64171
# open 3460.586454
# clsoe 3435.476794
# low 3418.681646
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3587.2442361
# SL_PRICE 3245.6019278999997
#
# INDEX 31
# COL 0
# high 3482.323556
# open 3435.406627
# clsoe 3464.166444
# low 3400.0
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3587.2442361
# SL_PRICE 3245.6019278999997
#
# INDEX 32
# COL 0
# high 3518.937773
# open 3464.166444
# clsoe 3505.695874
# low 3436.516682
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3587.2442361
# SL_PRICE 3245.6019278999997
#
# INDEX 33
# COL 0
# high 3505.695874
# open 3505.695874
# clsoe 3455.166043
# low 3427.031206
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3587.2442361
# SL_PRICE 3245.6019278999997
#
# INDEX 34
# COL 0
# high 3485.0
# open 3457.256026
# clsoe 3459.109573
# low 3430.000256
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3587.2442361
# SL_PRICE 3245.6019278999997
#
# INDEX 35
# COL 0
# high 3479.991522
# open 3457.280468
# clsoe 3466.120649
# low 3445.000006
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3587.2442361
# SL_PRICE 3245.6019278999997
#
# INDEX 36
# COL 0
# high 3480.553146
# open 3472.822004
# clsoe 3402.988749
# low 3382.197503
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3587.2442361
# SL_PRICE 3245.6019278999997
#
# INDEX 37
# COL 0
# high 3426.221983
# open 3402.988751
# clsoe 3395.393984
# low 3390.001002
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3587.2442361
# SL_PRICE 3245.6019278999997
#
# INDEX 38
# COL 0
# high 3731.534384
# open 3393.342918
# clsoe 3660.0
# low 3379.005494
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3587.2442361
# SL_PRICE 3245.6019278999997
#
# tp hit
# return value  Order(size=-1.0, price=3587.2442361, size_type=0, direction=0, fees=0.0, fixed_fees=0.0, slippage=0.0, min_size=0.0, max_size=inf, size_granularity=nan, reject_prob=0.0, lock_cash=False, allow_partial=True, raise_reject=False, log=False)
#
# INDEX 39
# COL 0
# high 3675.98
# open 3660.0
# clsoe 3660.272053
# low 3626.210808
# position size : 0.0
# TP_PRICE 0.0
# SL_PRICE 0.0
#
# INDEX 40
# COL 0
# high 3687.704134
# open 3668.137816
# clsoe 3682.697181
# low 3613.567539
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3843.2856556500005
# SL_PRICE 3477.2584503499997
#
# INDEX 41
# COL 0
# high 3666.331161
# open 3666.331161
# clsoe 3621.279969
# low 3615.752931
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3843.2856556500005
# SL_PRICE 3477.2584503499997
#
# INDEX 42
# COL 0
# high 3660.0
# open 3644.976124
# clsoe 3632.008858
# low 3580.182806
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3843.2856556500005
# SL_PRICE 3477.2584503499997
#
# INDEX 43
# COL 0
# high 3663.82986
# open 3632.924018
# clsoe 3609.000011
# low 3592.000009
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3843.2856556500005
# SL_PRICE 3477.2584503499997
#
# INDEX 44
# COL 0
# high 3627.672075
# open 3609.000003
# clsoe 3589.999998
# low 3570.961155
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3843.2856556500005
# SL_PRICE 3477.2584503499997
#
# INDEX 45
# COL 0
# high 3650.0
# open 3589.999998
# clsoe 3595.83462
# low 3571.787184
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3843.2856556500005
# SL_PRICE 3477.2584503499997
#
# INDEX 46
# COL 0
# high 3649.206298
# open 3596.969796
# clsoe 3615.410002
# low 3595.603349
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3843.2856556500005
# SL_PRICE 3477.2584503499997
#
# INDEX 47
# COL 0
# high 3698.059545
# open 3615.41
# clsoe 3665.246462
# low 3605.5
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3843.2856556500005
# SL_PRICE 3477.2584503499997
#
# INDEX 48
# COL 0
# high 3900.0
# open 3674.999999
# clsoe 3881.0
# low 3660.284026
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3843.2856556500005
# SL_PRICE 3477.2584503499997
#
# tp hit
# return value  Order(size=-1.0, price=3843.2856556500005, size_type=0, direction=0, fees=0.0, fixed_fees=0.0, slippage=0.0, min_size=0.0, max_size=inf, size_granularity=nan, reject_prob=0.0, lock_cash=False, allow_partial=True, raise_reject=False, log=False)
#
# INDEX 49
# COL 0
# high 3992.148135
# open 3881.00000001
# clsoe 3913.0
# low 3802.00000001
# position size : 0.0
# TP_PRICE 0.0
# SL_PRICE 0.0
#
# INDEX 50
# COL 0
# high 4050.0
# open 3910.50002727
# clsoe 3974.99139506
# low 3870.354929
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 4108.650000000001
# SL_PRICE 3717.35
#
# INDEX 51
# COL 0
# high 4013.75503992
# open 3973.126369
# clsoe 3937.647732
# low 3900.55121299
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 4108.650000000001
# SL_PRICE 3717.35
#
# INDEX 52
# COL 0
# high 3985.52778809
# open 3939.999999
# clsoe 3971.746659
# low 3928.96279679
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 4108.650000000001
# SL_PRICE 3717.35
#
# INDEX 53
# COL 0
# high 4158.08648551
# open 3959.14205667
# clsoe 4112.900968
# low 3934.81928255
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 4108.650000000001
# SL_PRICE 3717.35
#
# tp hit
# return value  Order(size=-1.0, price=4108.650000000001, size_type=0, direction=0, fees=0.0, fixed_fees=0.0, slippage=0.0, min_size=0.0, max_size=inf, size_granularity=nan, reject_prob=0.0, lock_cash=False, allow_partial=True, raise_reject=False, log=False)
#
# INDEX 54
# COL 0
# high 4198.47174203
# open 4112.900968
# clsoe 3750.6507972
# low 3714.32708055
# position size : 0.0
# TP_PRICE 0.0
# SL_PRICE 0.0
#
# INDEX 55
# COL 0
# high 3870.0
# open 3748.211143
# clsoe 3830.95429929
# low 3748.211143
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3938.18333706
# SL_PRICE 3563.1182573399997
#
# INDEX 56
# COL 0
# high 3849.999992
# open 3824.986869
# clsoe 3810.2960346
# low 3785.00000611
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3938.18333706
# SL_PRICE 3563.1182573399997
#
# INDEX 57
# COL 0
# high 3835.24660653
# open 3810.79603462
# clsoe 3816.3
# low 3690.0
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3938.18333706
# SL_PRICE 3563.1182573399997
#
# INDEX 58
# COL 0
# high 3885.0
# open 3814.01549251
# clsoe 3816.1300759
# low 3775.8066242
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3938.18333706
# SL_PRICE 3563.1182573399997
#
# INDEX 59
# COL 0
# high 3870.0
# open 3816.1300759
# clsoe 3821.6
# low 3810.05341961
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3938.18333706
# SL_PRICE 3563.1182573399997
#
# INDEX 60
# COL 0
# high 3841.5
# open 3821.6
# clsoe 3824.1
# low 3757.0
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3938.18333706
# SL_PRICE 3563.1182573399997
#
# INDEX 61
# COL 0
# high 3839.1
# open 3822.3
# clsoe 3805.8
# low 3781.1
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3938.18333706
# SL_PRICE 3563.1182573399997
#
# INDEX 62
# COL 0
# high 3826.7
# open 3806.2
# clsoe 3714.4
# low 3679.8
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3938.18333706
# SL_PRICE 3563.1182573399997
#
# INDEX 63
# COL 0
# high 3877.6
# open 3723.2
# clsoe 3855.0
# low 3702.9
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3938.18333706
# SL_PRICE 3563.1182573399997
#
# INDEX 64
# COL 0
# high 3889.0
# open 3855.0
# clsoe 3861.2
# low 3810.0
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3938.18333706
# SL_PRICE 3563.1182573399997
#
# INDEX 65
# COL 0
# high 3904.9
# open 3862.7
# clsoe 3869.9
# low 3845.0
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3938.18333706
# SL_PRICE 3563.1182573399997
#
# INDEX 66
# COL 0
# high 3932.3
# open 3873.9
# clsoe 3864.7
# low 3802.0
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3938.18333706
# SL_PRICE 3563.1182573399997
#
# INDEX 67
# COL 0
# high 3966.6
# open 3863.5
# clsoe 3942.3
# low 3856.2
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 3938.18333706
# SL_PRICE 3563.1182573399997
#
# tp hit
# return value  Order(size=-1.0, price=3938.18333706, size_type=0, direction=0, fees=0.0, fixed_fees=0.0, slippage=0.0, min_size=0.0, max_size=inf, size_granularity=nan, reject_prob=0.0, lock_cash=False, allow_partial=True, raise_reject=False, log=False)
#
# INDEX 68
# COL 0
# high 3940.3
# open 3940.1
# clsoe 3915.6
# low 3885.0
# position size : 0.0
# TP_PRICE 0.0
# SL_PRICE 0.0
#
# INDEX 69
# COL 0
# high 3935.4
# open 3915.1
# clsoe 3874.4
# low 3840.2
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 4111.38
# SL_PRICE 3719.8199999999997
#
# INDEX 70
# COL 0
# high 3909.2
# open 3872.2
# clsoe 3882.4
# low 3815.1
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 4111.38
# SL_PRICE 3719.8199999999997
#
# INDEX 71
# COL 0
# high 3896.8
# open 3885.8
# clsoe 3866.8
# low 3840.7
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 4111.38
# SL_PRICE 3719.8199999999997
#
# INDEX 72
# COL 0
# high 3920.0
# open 3863.2
# clsoe 3878.7
# low 3815.7
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 4111.38
# SL_PRICE 3719.8199999999997
#
# INDEX 73
# COL 0
# high 3935.0
# open 3878.7
# clsoe 3922.3
# low 3874.5
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 4111.38
# SL_PRICE 3719.8199999999997
#
# INDEX 74
# COL 0
# high 4050.0
# open 3923.6
# clsoe 4002.0
# low 3919.3
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 4111.38
# SL_PRICE 3719.8199999999997
#
# INDEX 75
# COL 0
# high 4006.9
# open 4002.1
# clsoe 3978.8
# low 3953.4
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 4111.38
# SL_PRICE 3719.8199999999997
#
# INDEX 76
# COL 0
# high 4035.0
# open 3978.9
# clsoe 3986.7
# low 3954.1
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 4111.38
# SL_PRICE 3719.8199999999997
#
# INDEX 77
# COL 0
# high 4028.2
# open 3987.1
# clsoe 4012.9
# low 3968.7
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 4111.38
# SL_PRICE 3719.8199999999997
#
# INDEX 78
# COL 0
# high 4026.8
# open 4014.8
# clsoe 4024.0
# low 3982.0
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 4111.38
# SL_PRICE 3719.8199999999997
#
# INDEX 79
# COL 0
# high 4063.2
# open 4019.3
# clsoe 3983.1
# low 3911.0
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 4111.38
# SL_PRICE 3719.8199999999997
#
# INDEX 80
# COL 0
# high 4019.2
# open 3981.4
# clsoe 3987.1
# low 3969.6
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 4111.38
# SL_PRICE 3719.8199999999997
#
# INDEX 81
# COL 0
# high 4018.8
# open 3987.1
# clsoe 4005.0
# low 3979.0
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 4111.38
# SL_PRICE 3719.8199999999997
#
# INDEX 82
# COL 0
# high 4019.9
# open 4005.0
# clsoe 3987.2
# low 3962.5
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 4111.38
# SL_PRICE 3719.8199999999997
#
# INDEX 83
# COL 0
# high 3999.0
# open 3987.2
# clsoe 3922.2
# low 3884.9
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 4111.38
# SL_PRICE 3719.8199999999997
#
# INDEX 84
# COL 0
# high 3948.0
# open 3922.2
# clsoe 3937.9
# low 3893.1
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 4111.38
# SL_PRICE 3719.8199999999997
#
# INDEX 85
# COL 0
# high 4033.3
# open 3937.9
# clsoe 4023.8
# low 3923.4
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 4111.38
# SL_PRICE 3719.8199999999997
#
# INDEX 86
# COL 0
# high 6950.0
# open 4018.1
# clsoe 4027.8
# low 4000.0
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 4111.38
# SL_PRICE 3719.8199999999997
#
# tp hit
# return value  Order(size=-1.0, price=4111.38, size_type=0, direction=0, fees=0.0, fixed_fees=0.0, slippage=0.0, min_size=0.0, max_size=inf, size_granularity=nan, reject_prob=0.0, lock_cash=False, allow_partial=True, raise_reject=False, log=False)
#
# INDEX 87
# COL 0
# high 4123.4
# open 4027.8
# clsoe 4098.9
# low 4022.7
# position size : 0.0
# TP_PRICE 0.0
# SL_PRICE 0.0
#
# INDEX 88
# COL 0
# high 4141.0
# open 4098.2
# clsoe 4108.1
# low 4060.2
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 4303.845
# SL_PRICE 3893.9549999999995
#
# INDEX 89
# COL 0
# high 4116.3
# open 4103.5
# clsoe 4103.7
# low 4086.0
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 4303.845
# SL_PRICE 3893.9549999999995
#
# INDEX 90
# COL 0
# high 4148.5
# open 4102.9
# clsoe 4142.0
# low 4074.3
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 4303.845
# SL_PRICE 3893.9549999999995
#
# INDEX 91
# COL 0
# high 4881.8
# open 4135.9
# clsoe 4848.8
# low 4131.8
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 4303.845
# SL_PRICE 3893.9549999999995
#
# tp hit
# return value  Order(size=-1.0, price=4303.845, size_type=0, direction=0, fees=0.0, fixed_fees=0.0, slippage=0.0, min_size=0.0, max_size=inf, size_granularity=nan, reject_prob=0.0, lock_cash=False, allow_partial=True, raise_reject=False, log=False)
#
# INDEX 92
# COL 0
# high 5300.0
# open 4848.8
# clsoe 4923.7
# low 4795.2
# position size : 0.0
# TP_PRICE 0.0
# SL_PRICE 0.0
#
# INDEX 93
# COL 0
# high 5040.3
# open 4923.7
# clsoe 4894.8
# low 4800.0
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 5169.885
# SL_PRICE 4677.514999999999
#
# INDEX 94
# COL 0
# high 5032.2
# open 4899.5
# clsoe 5000.4
# low 4875.5
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 5169.885
# SL_PRICE 4677.514999999999
#
# INDEX 95
# COL 0
# high 5199.0
# open 5000.0
# clsoe 5050.7
# low 4935.3
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 5169.885
# SL_PRICE 4677.514999999999
#
# tp hit
# return value  Order(size=-1.0, price=5169.885, size_type=0, direction=0, fees=0.0, fixed_fees=0.0, slippage=0.0, min_size=0.0, max_size=inf, size_granularity=nan, reject_prob=0.0, lock_cash=False, allow_partial=True, raise_reject=False, log=False)
#
# INDEX 96
# COL 0
# high 5225.4
# open 5044.3
# clsoe 5164.9
# low 5031.0
# position size : 0.0
# TP_PRICE 0.0
# SL_PRICE 0.0
#
# INDEX 97
# COL 0
# high 5300.0
# open 5166.0
# clsoe 5236.0
# low 5039.9
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 5423.1449999999995
# SL_PRICE 4906.655
#
# INDEX 98
# COL 0
# high 5241.0
# open 5241.0
# clsoe 5143.5
# low 5080.9
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 5423.1449999999995
# SL_PRICE 4906.655
#
# INDEX 99
# COL 0
# high 5400.0
# open 5143.5
# clsoe 5305.7
# low 5130.9
# position size : 1.0
# POSITION IS LONG
# TP_PRICE 5423.1449999999995
# SL_PRICE 4906.655
#
# Total Return: 0.13391061944600027
#
# Order Records:

# %% [markdown]
# ## ma cross overall trend prediction

# %%
def ma_cross_slow_indicator(close_price,window_slow,window_mid,window_fast):
    ema4 = vbt.MA.run(close_price, window=window_slow).ma.to_numpy()
    ema5 = vbt.MA.run(close_price, window=window_mid).ma.to_numpy()
    ema6 = vbt.MA.run(close_price, window=window_fast).ma.to_numpy()
    up = (ema4 > ema5) & (ema5 > ema6)
    down = (ema4 < ema5) & (ema5 < ema6)
    trend = np.where(up,1,np.where(down,-1,0))

    return trend


ma_cross_slow = vbt.IndicatorFactory(class_name='MA_Cross_slow',
                                     short_name='ma_c_slow',
                                     input_names=['Close'],
                                     param_names=['ema4', 'ema5', 'ema6'],
                                     output_names=['ma_cross_slow']
                                     ).from_apply_func(ma_cross_slow_indicator,ema4= 20, ema5=40,ema6=70)

# window_slow = [180,200]
# window_mid = [40,50]
# window_fast = [20,30]

window_slow = 180
window_mid = 40
window_fast = 20

trend = ma_cross_slow.run(btc_price['Close'],ema4= window_fast, ema5=window_mid,ema6=window_slow,param_product=True)
trend.ma_cross_slow
# Out:
# Open time
# 2019-01-01 00:00:00+00:00    0
# 2019-01-02 00:00:00+00:00    0
# 2019-01-03 00:00:00+00:00    0
# 2019-01-04 00:00:00+00:00    0
# 2019-01-05 00:00:00+00:00    0
#                             ..
# 2024-12-13 00:00:00+00:00    1
# 2024-12-14 00:00:00+00:00    1
# 2024-12-15 00:00:00+00:00    1
# 2024-12-16 00:00:00+00:00    1
# 2024-12-17 00:00:00+00:00    1
# Freq: D, Name: (20, 40, 180, Close), Length: 2178, dtype: int64

# %%
import vectorbt as vbt
import numpy as np

def ma_cross_rsi(close_price, ma1_window, ma2_window, ma3_window, ma4_window, ma5_window, rsi_buy_threshold, rsi_sell_threshold):
    ma1 = vbt.MA.run(close_price, window=ma1_window).ma.to_numpy()
    ma2 = vbt.MA.run(close_price, window=ma2_window).ma.to_numpy()
    ma3 = vbt.MA.run(close_price, window=ma3_window).ma.to_numpy()
    ma4 = vbt.MA.run(close_price, window=ma4_window).ma.to_numpy()
    ma5 = vbt.MA.run(close_price, window=ma5_window).ma.to_numpy()
    slow_trend_up = (ma4 > ma5)
    slow_trend_down = (ma4 < ma5)

    short_trend_up = (ma1 > ma2) & (ma2 > ma3)
    short_trend_undecided = (ma1 < ma2) & (ma2 > ma3)
    short_trend_down = (ma1 < ma2) & (ma2 < ma3)

    rsi = vbt.RSI.run(close_price, window=14).rsi.to_numpy()
    rsi_buy = rsi > rsi_buy_threshold
    rsi_sell = rsi < rsi_sell_threshold
    
    signal_buy = slow_trend_up & short_trend_up & rsi_buy
    signal_sell = slow_trend_down & short_trend_down & rsi_sell

    no_caution_long = slow_trend_up & short_trend_up
    caution_long1 = slow_trend_up & short_trend_undecided 
    caution_long2 = slow_trend_up & short_trend_down

    no_caution_short = slow_trend_down & short_trend_down
    caution_short1 = slow_trend_down & short_trend_undecided
    caution_short2 = slow_trend_down & short_trend_up

    conditions = [
        signal_buy,
        no_caution_long,
        caution_long1,
        caution_long2,
        signal_sell,
        no_caution_short,
        caution_short1,
        caution_short2
    ]

    values = [
        100,
        75,
        50,
        25,
        -100,
        -75,
        -50,
        -25
    ]


    # Use np.select to apply the conditions
    signal = np.select(conditions, values, default=0)
  
    # signal = np.where(signal_buy, 100, np.where(signal_sell, -100, sl_adjust_signal))

    return signal

ma_cross_slow = vbt.IndicatorFactory(
    class_name='MA_Cross_rsi',
    short_name='ma_c_slow',
    input_names=['Close'],
    param_names=['ma1', 'ma2', 'ma3', 'ma4', 'ma5', 'rsi_buy_threshold', 'rsi_sell_threshold'],
    output_names=['ma_cross_rsi']
).from_apply_func(ma_cross_rsi, ma1=20, ma2=30, ma3=40, ma4=125, ma5=150, rsi_buy_threshold=70, rsi_sell_threshold=30)

# Define window sizes and RSI thresholds
ma_trend_fast = 25
ma_trend_mid = 50
ma_trend_slow = 70

ma_slow_trend1 = 125
ma_slow_trend_2 = 150

rsi_buy_threshold = 70
rsi_sell_threshold = 30

# Run the indicator
trend = ma_cross_slow.run(
    btc_price['Close'],
    ma1=ma_trend_fast,
    ma2=ma_trend_mid,
    ma3=ma_trend_slow,
    ma4=ma_slow_trend1,
    ma5=ma_slow_trend_2,
    rsi_buy_threshold=rsi_buy_threshold,
    rsi_sell_threshold=rsi_sell_threshold,
    param_product=True
)
trend.ma_cross_rsi.head(150)
# Out:
# Open time
# 2019-01-01 00:00:00+00:00     0
# 2019-01-02 00:00:00+00:00     0
# 2019-01-03 00:00:00+00:00     0
# 2019-01-04 00:00:00+00:00     0
# 2019-01-05 00:00:00+00:00     0
#                              ..
# 2019-05-26 00:00:00+00:00     0
# 2019-05-27 00:00:00+00:00     0
# 2019-05-28 00:00:00+00:00     0
# 2019-05-29 00:00:00+00:00     0
# 2019-05-30 00:00:00+00:00    75
# Freq: D, Name: (25, 50, 70, 125, 150, 70, 30, Close), Length: 150, dtype: int64

# %%
import vectorbt as vbt
import numpy as np

def ma_cross_rsi(close_price, ma1_window, ma2_window, ma3_window, ma4_window, ma5_window, rsi_buy_threshold, rsi_sell_threshold):
    # Calculate moving averages
    ma1 = vbt.MA.run(close_price, window=ma1_window).ma.to_numpy()
    ma2 = vbt.MA.run(close_price, window=ma2_window).ma.to_numpy()
    ma3 = vbt.MA.run(close_price, window=ma3_window).ma.to_numpy()
    ma4 = vbt.MA.run(close_price, window=ma4_window).ma.to_numpy()
    ma5 = vbt.MA.run(close_price, window=ma5_window).ma.to_numpy()
    
    # Determine slow trend direction
    slow_trend_up = (ma4 > ma5)
    slow_trend_down = (ma4 < ma5)

    # Determine short trend direction
    short_trend_up = (ma1 > ma2) & (ma2 > ma3)
    short_trend_undecided = (ma1 < ma2) & (ma2 > ma3)
    short_trend_down = (ma1 < ma2) & (ma2 < ma3)

    # Calculate RSI and determine buy/sell signals
    rsi = vbt.RSI.run(close_price, window=14).rsi.to_numpy()
    rsi_buy = rsi > rsi_buy_threshold
    rsi_sell = rsi < rsi_sell_threshold
    
    # Generate buy and sell signals
    signal_buy = slow_trend_up & short_trend_up & rsi_buy
    signal_sell = slow_trend_down & short_trend_down & rsi_sell

    # Define caution signals for long and short positions
    no_caution_long = slow_trend_up & short_trend_up
    caution_long1 = slow_trend_up & short_trend_undecided 
    caution_long2 = slow_trend_up & short_trend_down

    no_caution_short = slow_trend_down & short_trend_down
    caution_short1 = slow_trend_down & short_trend_undecided
    caution_short2 = slow_trend_down & short_trend_up

    # Define conditions and corresponding values for signals
    conditions = [
        signal_buy,
        no_caution_long,
        caution_long1,
        caution_long2,
        signal_sell,
        no_caution_short,
        caution_short1,
        caution_short2
    ]

    values = [
        100,  # Strong buy signal (slow trend up, short trend up, and RSI above the buy threshold)
        75,   # No caution long (slow trend up and short trend up)
        50,   # Caution long 1 (slow trend up and short trend undecided)
        25,   # Caution long 2 (slow trend up and short trend down)
        -100, # Strong sell signal (slow trend down, short trend down, and RSI below the sell threshold)
        -75,  # No caution short (slow trend down and short trend down)
        -50,  # Caution short 1 (slow trend down and short trend undecided)
        -25   # Caution short 2 (slow trend down and short trend up)
    ]

    # Use np.select to apply the conditions and assign the corresponding values
    signal = np.select(conditions, values, default=0)  # 0: No signal (default value when none of the conditions are met)

    return signal

# Create the indicator factory
ma_cross_slow = vbt.IndicatorFactory(
    class_name='MA_Cross_rsi',
    short_name='ma_c_slow',
    input_names=['Close'],
    param_names=['ma1', 'ma2', 'ma3', 'ma4', 'ma5', 'rsi_buy_threshold', 'rsi_sell_threshold'],
    output_names=['ma_cross_rsi']
).from_apply_func(ma_cross_rsi, ma1=20, ma2=30, ma3=40, ma4=125, ma5=150, rsi_buy_threshold=70, rsi_sell_threshold=30)

# Define window sizes and RSI thresholds
ma_trend_fast = 25
ma_trend_mid = 50
ma_trend_slow = 70

ma_slow_trend1 = 125
ma_slow_trend_2 = 150

rsi_buy_threshold = 70
rsi_sell_threshold = 30

# Run the indicator
trend = ma_cross_slow.run(
    btc_price['Close'],
    ma1=ma_trend_fast,
    ma2=ma_trend_mid,
    ma3=ma_trend_slow,
    ma4=ma_slow_trend1,
    ma5=ma_slow_trend_2,
    rsi_buy_threshold=rsi_buy_threshold,
    rsi_sell_threshold=rsi_sell_threshold,
    param_product=True
)

# Display the first 150 rows of the signal output
trend.ma_cross_rsi.head(150)
# Out:
# Open time
# 2019-01-01 00:00:00+00:00     0
# 2019-01-02 00:00:00+00:00     0
# 2019-01-03 00:00:00+00:00     0
# 2019-01-04 00:00:00+00:00     0
# 2019-01-05 00:00:00+00:00     0
#                              ..
# 2019-05-26 00:00:00+00:00     0
# 2019-05-27 00:00:00+00:00     0
# 2019-05-28 00:00:00+00:00     0
# 2019-05-29 00:00:00+00:00     0
# 2019-05-30 00:00:00+00:00    75
# Freq: D, Name: (25, 50, 70, 125, 150, 70, 30, Close), Length: 150, dtype: int64

# %%
import numpy as np
import pandas as pd
import vectorbt as vbt
from numba import njit
from vectorbt.portfolio.enums import Direction, SizeType

# Create sample price data
btc_price2 = btc_price.copy()
close_price = btc_price2['Close']

# Assume btc_price['Close'], btc_price['High'], btc_price['Low'], and btc_price['Open'] are Series
close = btc_price['Close'].to_numpy()
high = btc_price['High'].to_numpy()
low = btc_price['Low'].to_numpy()
open_ = btc_price['Open'].to_numpy()
btc_price2 = btc_price.to_numpy()
entries = trend.ma_cross_slow.to_numpy()

# Create an array to store SL prices
sl_prices = np.full(close.shape[0], np.nan)  # Use a 1D array



# Numba-compiled order function
@njit
def order_func_nb(c, high, low, open_, entries, sl_prices):
    close_price = c.close[c.i, c.col]
    print("INDEX", c.i)
    print("COL", c.col)
    print("high", high[c.i])
    print('open', open_[c.i])
    print("close", close_price)
    print('low', low[c.i])
    print('position size :', c.position_now)
    print('cash:', c.cash_now)
    print('entries:', entries[c.i])
    print()

# if in position 
    if (c.position_now > 0):
        # Check if SL is hit
        if low[c.i-1] <= sl_prices[c.i]:
            value = vbt.portfolio.nb.order_nb(
                size=-np.inf,  # Close position
                price=sl_prices[c.i],
                size_type=SizeType.Amount,
                direction=Direction.LongOnly)

            print('sl hit at:', c.i, sl_prices[c.i])
            print("return value ", value)
            return value
        
        # check condition to adjust sl 
        # find lowest low in the last 5 bars
        # set sl n% lower than the lowest low
        # if new sl is higher than the current sl update
        # if new sl is lower than the current sl do nothing

        if c.i >= 5:  # Ensure there are enough bars to look back
            lowest_low = np.min(low[c.i-5:c.i])  # Find the lowest low in the last 5 bars
            new_sl_price = lowest_low * 0.90  # Set SL n% lower than the lowest low
            if new_sl_price > sl_prices[c.i]:
                if (entries[c.i] == 1):
                    print('sl update before',c.i,sl_prices[c.i])
                    sl_prices[:]= close_price * 0.90 # Calculate SL price
                    print('sl update after at index',c.i,sl_prices[c.i])
                if (entries[c.i] == 0):            
                    print('sl update before',c.i,sl_prices[c.i])
                    sl_prices[:]= close_price * 0.95 # Calculate SL price
                    print('sl update after at index',c.i,sl_prices[c.i])


    # if not in position search for position to enter
    elif (c.position_now == 0) & (c.i != 0):
        if entries[c.i] == 1:
            sl_price = close_price * 0.90
            order = vbt.portfolio.nb.order_nb(
                size=0.1,  # Adjusted order size
                price=close_price,  # Current closing price
                size_type=SizeType.Percent,  # Specify size type
                direction=Direction.LongOnly,  # Long-only trading
                fees=0.0,  # No fees
                slippage=0.0,  # No slippage
                allow_partial=False,  # Do not allow partial fills
                raise_reject=True  # Raise an error if the order is rejected
            )
            sl_prices[:] = sl_price 
            print('sl to put in array price:', sl_price)
            print('sl array',sl_prices[1])   # Save the SL price using a single index
            print('long order', c.i,order)
            print()
            return order
    


    return vbt.portfolio.enums.NoOrder


# Create portfolio
pf = vbt.Portfolio.from_order_func(
    close_price,           # Price DataFrame
    order_func_nb,
    high,
    low,
    open_,
    entries,    # Order function
    sl_prices,  # Pass the SL prices array
    init_cash=100000,  # Initial cash balance
)

# Display some portfolio performance metrics
print("Total Return:", pf.total_return())
print("\nOrder Records:")

pf.orders.records_readable
# Optional: Plot equity curve
pf.plot().show()
# Out:
# INDEX 0
# COL 0
# high 3805.841739
# open 3700.170853
# close 3799.644687
# low 3645.525763
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 1
# COL 0
# high 3880.257733
# open 3799.644687
# close 3856.504318
# low 3750.000001
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 2
# COL 0
# high 3862.60083
# open 3857.633097
# close 3765.999334
# low 3728.917225
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 3
# COL 0
# high 3821.195343
# open 3767.8543
# close 3791.46126
# low 3706.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 4
# COL 0
# high 3838.67454
# open 3789.0
# close 3772.156039
# low 3756.410862
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 5
# COL 0
# high 4023.0
# open 3775.703265
# close 3988.471816
# low 3746.584563
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 6
# COL 0
# high 4017.71888
# open 3984.865903
# close 3972.264189
# low 3927.799365
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 7
# COL 0
# high 4061.280555
# open 3977.721738
# close 3956.635321
# low 3925.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 8
# COL 0
# high 3999.999999
# open 3953.740659
# close 3967.16117
# low 3940.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 9
# COL 0
# high 3995.174297
# open 3962.210833
# close 3582.995912
# low 3538.410921
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 10
# COL 0
# high 3647.694494
# open 3582.670179
# close 3601.765191
# low 3532.298156
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 11
# COL 0
# high 3615.341123
# open 3601.765191
# close 3588.336328
# low 3536.275592
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 12
# COL 0
# high 3620.330298
# open 3586.944215
# close 3470.442417
# low 3446.953248
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 13
# COL 0
# high 3668.902955
# open 3477.754986
# close 3625.940976
# low 3465.964471
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 14
# COL 0
# high 3644.873222
# open 3621.054803
# close 3558.825309
# low 3523.408177
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 15
# COL 0
# high 3637.545485
# open 3553.0
# close 3585.539637
# low 3544.18794
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 16
# COL 0
# high 3629.854475
# open 3590.559117
# close 3613.059078
# low 3536.929827
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 17
# COL 0
# high 3621.231797
# open 3621.231797
# close 3598.563462
# low 3569.950664
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 18
# COL 0
# high 3713.263735
# open 3606.551267
# close 3669.514623
# low 3592.39684
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 19
# COL 0
# high 3694.320724
# open 3666.0
# close 3541.961501
# low 3482.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 20
# COL 0
# high 3556.419913
# open 3540.956207
# close 3528.160647
# low 3491.426433
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 21
# COL 0
# high 3602.428923
# open 3525.618845
# close 3573.882315
# low 3448.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 22
# COL 0
# high 3605.0
# open 3570.777944
# close 3553.668236
# low 3516.745198
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 23
# COL 0
# high 3585.98651
# open 3548.001237
# close 3565.610748
# low 3526.756089
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 24
# COL 0
# high 3577.898931
# open 3567.534218
# close 3571.590258
# low 3520.682464
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 25
# COL 0
# high 3653.931361
# open 3566.918941
# close 3564.413089
# low 3549.796545
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 26
# COL 0
# high 3581.399326
# open 3564.41309
# close 3556.026201
# low 3500.496895
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 27
# COL 0
# high 3559.997922
# open 3548.928346
# close 3439.084664
# low 3385.98654
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 28
# COL 0
# high 3445.666304
# open 3432.386812
# close 3416.423082
# low 3352.150773
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 29
# COL 0
# high 3479.461934
# open 3407.693594
# close 3465.360373
# low 3380.00245
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 30
# COL 0
# high 3494.64171
# open 3460.586454
# close 3435.476794
# low 3418.681646
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 31
# COL 0
# high 3482.323556
# open 3435.406627
# close 3464.166444
# low 3400.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 32
# COL 0
# high 3518.937773
# open 3464.166444
# close 3505.695874
# low 3436.516682
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 33
# COL 0
# high 3505.695874
# open 3505.695874
# close 3455.166043
# low 3427.031206
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 34
# COL 0
# high 3485.0
# open 3457.256026
# close 3459.109573
# low 3430.000256
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 35
# COL 0
# high 3479.991522
# open 3457.280468
# close 3466.120649
# low 3445.000006
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 36
# COL 0
# high 3480.553146
# open 3472.822004
# close 3402.988749
# low 3382.197503
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 37
# COL 0
# high 3426.221983
# open 3402.988751
# close 3395.393984
# low 3390.001002
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 38
# COL 0
# high 3731.534384
# open 3393.342918
# close 3660.0
# low 3379.005494
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 39
# COL 0
# high 3675.98
# open 3660.0
# close 3660.272053
# low 3626.210808
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 40
# COL 0
# high 3687.704134
# open 3668.137816
# close 3682.697181
# low 3613.567539
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 41
# COL 0
# high 3666.331161
# open 3666.331161
# close 3621.279969
# low 3615.752931
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 42
# COL 0
# high 3660.0
# open 3644.976124
# close 3632.008858
# low 3580.182806
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 43
# COL 0
# high 3663.82986
# open 3632.924018
# close 3609.000011
# low 3592.000009
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 44
# COL 0
# high 3627.672075
# open 3609.000003
# close 3589.999998
# low 3570.961155
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 45
# COL 0
# high 3650.0
# open 3589.999998
# close 3595.83462
# low 3571.787184
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 46
# COL 0
# high 3649.206298
# open 3596.969796
# close 3615.410002
# low 3595.603349
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 47
# COL 0
# high 3698.059545
# open 3615.41
# close 3665.246462
# low 3605.5
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 48
# COL 0
# high 3900.0
# open 3674.999999
# close 3881.0
# low 3660.284026
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 49
# COL 0
# high 3992.148135
# open 3881.00000001
# close 3913.0
# low 3802.00000001
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 50
# COL 0
# high 4050.0
# open 3910.50002727
# close 3974.99139506
# low 3870.354929
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 51
# COL 0
# high 4013.75503992
# open 3973.126369
# close 3937.647732
# low 3900.55121299
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 52
# COL 0
# high 3985.52778809
# open 3939.999999
# close 3971.746659
# low 3928.96279679
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 53
# COL 0
# high 4158.08648551
# open 3959.14205667
# close 4112.900968
# low 3934.81928255
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 54
# COL 0
# high 4198.47174203
# open 4112.900968
# close 3750.6507972
# low 3714.32708055
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 55
# COL 0
# high 3870.0
# open 3748.211143
# close 3830.95429929
# low 3748.211143
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 56
# COL 0
# high 3849.999992
# open 3824.986869
# close 3810.2960346
# low 3785.00000611
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 57
# COL 0
# high 3835.24660653
# open 3810.79603462
# close 3816.3
# low 3690.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 58
# COL 0
# high 3885.0
# open 3814.01549251
# close 3816.1300759
# low 3775.8066242
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 59
# COL 0
# high 3870.0
# open 3816.1300759
# close 3821.6
# low 3810.05341961
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 60
# COL 0
# high 3841.5
# open 3821.6
# close 3824.1
# low 3757.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 61
# COL 0
# high 3839.1
# open 3822.3
# close 3805.8
# low 3781.1
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 62
# COL 0
# high 3826.7
# open 3806.2
# close 3714.4
# low 3679.8
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 63
# COL 0
# high 3877.6
# open 3723.2
# close 3855.0
# low 3702.9
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 64
# COL 0
# high 3889.0
# open 3855.0
# close 3861.2
# low 3810.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 65
# COL 0
# high 3904.9
# open 3862.7
# close 3869.9
# low 3845.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 66
# COL 0
# high 3932.3
# open 3873.9
# close 3864.7
# low 3802.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 67
# COL 0
# high 3966.6
# open 3863.5
# close 3942.3
# low 3856.2
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 68
# COL 0
# high 3940.3
# open 3940.1
# close 3915.6
# low 3885.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 69
# COL 0
# high 3935.4
# open 3915.1
# close 3874.4
# low 3840.2
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 70
# COL 0
# high 3909.2
# open 3872.2
# close 3882.4
# low 3815.1
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 71
# COL 0
# high 3896.8
# open 3885.8
# close 3866.8
# low 3840.7
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 72
# COL 0
# high 3920.0
# open 3863.2
# close 3878.7
# low 3815.7
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 73
# COL 0
# high 3935.0
# open 3878.7
# close 3922.3
# low 3874.5
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 74
# COL 0
# high 4050.0
# open 3923.6
# close 4002.0
# low 3919.3
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 75
# COL 0
# high 4006.9
# open 4002.1
# close 3978.8
# low 3953.4
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 76
# COL 0
# high 4035.0
# open 3978.9
# close 3986.7
# low 3954.1
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 77
# COL 0
# high 4028.2
# open 3987.1
# close 4012.9
# low 3968.7
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 78
# COL 0
# high 4026.8
# open 4014.8
# close 4024.0
# low 3982.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 79
# COL 0
# high 4063.2
# open 4019.3
# close 3983.1
# low 3911.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 80
# COL 0
# high 4019.2
# open 3981.4
# close 3987.1
# low 3969.6
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 81
# COL 0
# high 4018.8
# open 3987.1
# close 4005.0
# low 3979.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 82
# COL 0
# high 4019.9
# open 4005.0
# close 3987.2
# low 3962.5
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 83
# COL 0
# high 3999.0
# open 3987.2
# close 3922.2
# low 3884.9
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 84
# COL 0
# high 3948.0
# open 3922.2
# close 3937.9
# low 3893.1
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 85
# COL 0
# high 4033.3
# open 3937.9
# close 4023.8
# low 3923.4
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 86
# COL 0
# high 6950.0
# open 4018.1
# close 4027.8
# low 4000.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 87
# COL 0
# high 4123.4
# open 4027.8
# close 4098.9
# low 4022.7
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 88
# COL 0
# high 4141.0
# open 4098.2
# close 4108.1
# low 4060.2
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 89
# COL 0
# high 4116.3
# open 4103.5
# close 4103.7
# low 4086.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 90
# COL 0
# high 4148.5
# open 4102.9
# close 4142.0
# low 4074.3
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 91
# COL 0
# high 4881.8
# open 4135.9
# close 4848.8
# low 4131.8
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 92
# COL 0
# high 5300.0
# open 4848.8
# close 4923.7
# low 4795.2
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 93
# COL 0
# high 5040.3
# open 4923.7
# close 4894.8
# low 4800.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 94
# COL 0
# high 5032.2
# open 4899.5
# close 5000.4
# low 4875.5
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 95
# COL 0
# high 5199.0
# open 5000.0
# close 5050.7
# low 4935.3
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 96
# COL 0
# high 5225.4
# open 5044.3
# close 5164.9
# low 5031.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 97
# COL 0
# high 5300.0
# open 5166.0
# close 5236.0
# low 5039.9
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 98
# COL 0
# high 5241.0
# open 5241.0
# close 5143.5
# low 5080.9
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 99
# COL 0
# high 5400.0
# open 5143.5
# close 5305.7
# low 5130.9
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 100
# COL 0
# high 5332.4
# open 5307.6
# close 5016.0
# low 4926.4
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 101
# COL 0
# high 5075.0
# open 5018.0
# close 5050.6
# low 4873.8
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 102
# COL 0
# high 5091.6
# open 5051.6
# close 5041.7
# low 5005.5
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 103
# COL 0
# high 5148.9
# open 5045.8
# close 5133.7
# low 5002.5
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 104
# COL 0
# high 5167.2
# open 5134.6
# close 5030.7
# low 4950.1
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 105
# COL 0
# high 5192.3
# open 5027.4
# close 5174.0
# low 5004.7
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 106
# COL 0
# high 5227.5
# open 5173.8
# close 5199.8
# low 5153.9
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 107
# COL 0
# high 5285.0
# open 5200.0
# close 5260.1
# low 5194.4
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 108
# COL 0
# high 5324.2
# open 5256.8
# close 5260.6
# low 5183.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 109
# COL 0
# high 5330.5
# open 5258.7
# close 5292.4
# low 5235.5
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 110
# COL 0
# high 5310.4
# open 5293.5
# close 5258.5
# low 5172.4
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 111
# COL 0
# high 5395.5
# open 5257.8
# close 5355.2
# low 5207.6
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 112
# COL 0
# high 5599.9
# open 5354.9
# close 5494.3
# low 5338.5
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 113
# COL 0
# high 5578.9
# open 5494.4
# close 5415.3
# low 5346.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 114
# COL 0
# high 5485.2
# open 5415.3
# close 5221.9
# low 5137.5
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 115
# COL 0
# high 5515.5
# open 5221.9
# close 5311.8
# low 5169.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 116
# COL 0
# high 5339.4
# open 5312.1
# close 5296.0
# low 5262.1
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 117
# COL 0
# high 5700.0
# open 5295.0
# close 5312.4
# low 5271.9
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 118
# COL 0
# high 5334.5
# open 5310.0
# close 5238.5
# low 5189.6
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 119
# COL 0
# high 5340.6
# open 5239.1
# close 5319.6
# low 5194.3
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 120
# COL 0
# high 5398.5
# open 5323.4
# close 5386.2
# low 5318.2
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 121
# COL 0
# high 5537.9
# open 5382.5
# close 5495.3
# low 5372.1
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 122
# COL 0
# high 5842.6
# open 5496.1
# close 5769.4
# low 5483.5
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 123
# COL 0
# high 5901.9
# open 5769.5
# close 5832.6
# low 5598.8
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 124
# COL 0
# high 5833.3
# open 5832.3
# close 5773.6
# low 5703.2
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 125
# COL 0
# high 5801.1
# open 5771.8
# close 5746.4
# low 5619.6
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 126
# COL 0
# high 6027.7
# open 5749.0
# close 5844.3
# low 5748.3
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 127
# COL 0
# high 6015.7
# open 5846.9
# close 5980.1
# low 5800.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 128
# COL 0
# high 6244.9
# open 5984.8
# close 6208.4
# low 5981.5
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 129
# COL 0
# high 6453.1
# open 6208.4
# close 6377.8
# low 6144.3
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 130
# COL 0
# high 7385.0
# open 6377.8
# close 7190.8
# low 6377.7
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 131
# COL 0
# high 7513.9
# open 7187.9
# close 6976.1
# low 6785.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 132
# COL 0
# high 8102.1
# open 6974.1
# close 7804.9
# low 6878.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 133
# COL 0
# high 8344.2
# open 7812.6
# close 8001.4
# low 7679.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 134
# COL 0
# high 8250.0
# open 8000.0
# close 8180.9
# low 7830.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 135
# COL 0
# high 8319.9
# open 8180.9
# close 7859.0
# low 7717.2
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 136
# COL 0
# high 7923.3
# open 7860.1
# close 7354.1
# low 6927.7
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 137
# COL 0
# high 7460.2
# open 7354.1
# close 7258.4
# low 7192.3
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 138
# COL 0
# high 8270.5
# open 7254.6
# close 8157.2
# low 7247.8
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 139
# COL 0
# high 8156.2
# open 8154.3
# close 7936.2
# low 7562.3
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 140
# COL 0
# high 8043.0
# open 7935.6
# close 7904.2
# low 7780.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 141
# COL 0
# high 8009.5
# open 7904.2
# close 7622.8
# low 7512.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 142
# COL 0
# high 7939.1
# open 7625.8
# close 7853.4
# low 7470.5
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 143
# COL 0
# high 8111.1
# open 7852.8
# close 7962.6
# low 7773.4
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 144
# COL 0
# high 8085.3
# open 7962.6
# close 8025.1
# low 7910.5
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 145
# COL 0
# high 8727.9
# open 8024.9
# close 8615.7
# low 7857.2
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 146
# COL 0
# high 8900.1
# open 8616.9
# close 8758.0
# low 8594.9
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 147
# COL 0
# high 8793.0
# open 8753.5
# close 8718.0
# low 8544.2
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 148
# COL 0
# high 8750.0
# open 8718.0
# close 8644.9
# low 8415.4
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 149
# COL 0
# high 9068.9
# open 8643.5
# close 8262.2
# low 8032.8
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 150
# COL 0
# high 8578.0
# open 8262.4
# close 8555.6
# low 8111.5
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 151
# COL 0
# high 8624.0
# open 8555.6
# close 8545.5
# low 8445.7
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 152
# COL 0
# high 8807.3
# open 8545.4
# close 8721.9
# low 8527.5
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 153
# COL 0
# high 8730.4
# open 8724.7
# close 8134.2
# low 8097.8
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 154
# COL 0
# high 8134.2
# open 8134.1
# close 7683.2
# low 7500.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 155
# COL 0
# high 7899.2
# open 7685.1
# close 7782.1
# low 7577.4
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 156
# COL 0
# high 7855.0
# open 7781.5
# close 7782.8
# low 7456.5
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 157
# COL 0
# high 8094.3
# open 7785.0
# close 7974.8
# low 7747.7
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 158
# COL 0
# high 8041.1
# open 7981.5
# close 7893.6
# low 7767.2
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 159
# COL 0
# high 7934.8
# open 7898.1
# close 7631.1
# low 7501.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 160
# COL 0
# high 8013.5
# open 7631.2
# close 7985.8
# low 7513.4
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 161
# COL 0
# high 8010.4
# open 7986.4
# close 7881.5
# low 7700.3
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 162
# COL 0
# high 8199.0
# open 7885.4
# close 8127.6
# low 7795.4
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 163
# COL 0
# high 8308.9
# open 8132.0
# close 8218.9
# low 8017.8
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 164
# COL 0
# high 8678.3
# open 8218.9
# close 8648.2
# low 8153.6
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 165
# COL 0
# high 8850.0
# open 8648.2
# close 8811.4
# low 8578.6
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 166
# COL 0
# high 9328.3
# open 8810.0
# close 8956.9
# low 8768.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 167
# COL 0
# high 9439.0
# open 8954.2
# close 9310.2
# low 8954.1
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 168
# COL 0
# high 9338.3
# open 9311.4
# close 9082.3
# low 8963.9
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 169
# COL 0
# high 9293.4
# open 9082.4
# close 9256.2
# low 9043.2
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 170
# COL 0
# high 9586.6
# open 9249.7
# close 9513.2
# low 9182.2
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 171
# COL 0
# high 10171.3
# open 9513.2
# close 10153.1
# low 9513.2
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 172
# COL 0
# high 11148.4
# open 10159.3
# close 10739.7
# low 9975.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 173
# COL 0
# high 11374.5
# open 10739.8
# close 10890.6
# low 10551.6
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 174
# COL 0
# high 11132.1
# open 10890.8
# close 11048.0
# low 10628.1
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 175
# COL 0
# high 11842.2
# open 11041.6
# close 11815.4
# low 11033.8
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 176
# COL 0
# high 13947.7
# open 11820.0
# close 13067.3
# low 11743.1
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 177
# COL 0
# high 13427.6
# open 13067.4
# close 11329.8
# low 10542.7
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 178
# COL 0
# high 12474.2
# open 11317.4
# close 12409.5
# low 10996.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 179
# COL 0
# high 12436.6
# open 12412.7
# close 11892.9
# low 11479.6
# position size : 0.0
# cash: 100000.0
# entries: 1
#
# sl to put in array price: 10703.61
# sl array 10703.61
# long order 179 Order(size=0.1, price=11892.9, size_type=2, direction=0, fees=0.0, fixed_fees=0.0, slippage=0.0, min_size=0.0, max_size=inf, size_granularity=nan, reject_prob=0.0, lock_cash=False, allow_partial=False, raise_reject=True, log=False)
#
# INDEX 180
# COL 0
# high 12182.5
# open 11891.8
# close 10831.1
# low 10770.4
# position size : 0.8408378107946758
# cash: 90000.0
# entries: 1
#
# INDEX 181
# COL 0
# high 11251.3
# open 10831.1
# close 10630.3
# low 10042.2
# position size : 0.8408378107946758
# cash: 90000.0
# entries: 1
#
# INDEX 182
# COL 0
# high 10928.6
# open 10619.5
# close 10836.7
# low 9750.0
# position size : 0.8408378107946758
# cash: 90000.0
# entries: 1
#
# sl hit at: 182 10703.61
# return value  Order(size=-inf, price=10703.61, size_type=0, direction=0, fees=0.0, fixed_fees=0.0, slippage=0.0, min_size=0.0, max_size=inf, size_granularity=nan, reject_prob=0.0, lock_cash=False, allow_partial=True, raise_reject=False, log=False)
# INDEX 183
# COL 0
# high 11974.0
# open 10828.9
# close 11933.3
# low 10828.9
# position size : 0.0
# cash: 99000.0
# entries: 1
#
# sl to put in array price: 10739.97
# sl array 10739.97
# long order 183 Order(size=0.1, price=11933.3, size_type=2, direction=0, fees=0.0, fixed_fees=0.0, slippage=0.0, min_size=0.0, max_size=inf, size_granularity=nan, reject_prob=0.0, lock_cash=False, allow_partial=False, raise_reject=True, log=False)
#
# INDEX 184
# COL 0
# high 11994.0
# open 11924.3
# close 11158.9
# low 11083.1
# position size : 0.8296112558973628
# cash: 89100.0
# entries: 1
#
# INDEX 185
# COL 0
# high 11397.9
# open 11161.3
# close 10973.1
# low 10808.2
# position size : 0.8296112558973628
# cash: 89100.0
# entries: 1
#
# INDEX 186
# COL 0
# high 11650.8
# open 10971.0
# close 11253.6
# low 10965.1
# position size : 0.8296112558973628
# cash: 89100.0
# entries: 1
#
# INDEX 187
# COL 0
# high 11526.5
# open 11253.5
# close 11414.5
# low 11107.6
# position size : 0.8296112558973628
# cash: 89100.0
# entries: 1
#
# INDEX 188
# COL 0
# high 12338.0
# open 11413.7
# close 12249.0
# low 11296.4
# position size : 0.8296112558973628
# cash: 89100.0
# entries: 1
#
# INDEX 189
# COL 0
# high 12788.0
# open 12242.8
# close 12533.8
# low 12097.6
# position size : 0.8296112558973628
# cash: 89100.0
# entries: 1
#
# INDEX 190
# COL 0
# high 13139.0
# open 12537.0
# close 12101.0
# low 11572.2
# position size : 0.8296112558973628
# cash: 89100.0
# entries: 1
#
# INDEX 191
# COL 0
# high 12101.2
# open 12097.0
# close 11335.6
# low 11011.0
# position size : 0.8296112558973628
# cash: 89100.0
# entries: 1
#
# INDEX 192
# COL 0
# high 11880.4
# open 11338.7
# close 11760.0
# low 11101.3
# position size : 0.8296112558973628
# cash: 89100.0
# entries: 1
#
# INDEX 193
# COL 0
# high 11795.0
# open 11757.4
# close 11356.6
# low 10850.0
# position size : 0.8296112558973628
# cash: 89100.0
# entries: 1
#
# INDEX 194
# COL 0
# high 11444.0
# open 11350.5
# close 10185.8
# low 10101.9
# position size : 0.8296112558973628
# cash: 89100.0
# entries: 1
#
# INDEX 195
# COL 0
# high 11071.4
# open 10185.8
# close 10854.0
# low 9857.8
# position size : 0.8296112558973628
# cash: 89100.0
# entries: 1
#
# sl hit at: 195 10739.97
# return value  Order(size=-inf, price=10739.97, size_type=0, direction=0, fees=0.0, fixed_fees=0.0, slippage=0.0, min_size=0.0, max_size=inf, size_granularity=nan, reject_prob=0.0, lock_cash=False, allow_partial=True, raise_reject=False, log=False)
# INDEX 196
# COL 0
# high 11028.0
# open 10836.0
# close 9430.6
# low 9352.2
# position size : 0.0
# cash: 98010.0
# entries: 1
#
# sl to put in array price: 8487.54
# sl array 8487.54
# long order 196 Order(size=0.1, price=9430.6, size_type=2, direction=0, fees=0.0, fixed_fees=0.0, slippage=0.0, min_size=0.0, max_size=inf, size_granularity=nan, reject_prob=0.0, lock_cash=False, allow_partial=False, raise_reject=True, log=False)
#
# INDEX 197
# COL 0
# high 9950.0
# open 9435.7
# close 9669.1
# low 9072.5
# position size : 1.0392763981082858
# cash: 88209.0
# entries: 1
#
# INDEX 198
# COL 0
# high 10771.0
# open 9666.6
# close 10621.8
# low 9283.3
# position size : 1.0392763981082858
# cash: 88209.0
# entries: 1
#
# INDEX 199
# COL 0
# high 10752.1
# open 10629.3
# close 10502.9
# low 10131.2
# position size : 1.0392763981082858
# cash: 88209.0
# entries: 1
#
# INDEX 200
# COL 0
# high 11053.3
# open 10503.2
# close 10732.1
# low 10371.3
# position size : 1.0392763981082858
# cash: 88209.0
# entries: 1
#
# INDEX 201
# COL 0
# high 10808.0
# open 10734.9
# close 10579.3
# low 10310.0
# position size : 1.0392763981082858
# cash: 88209.0
# entries: 1
#
# INDEX 202
# COL 0
# high 10670.5
# open 10579.6
# close 10338.8
# low 10097.9
# position size : 1.0392763981082858
# cash: 88209.0
# entries: 1
#
# INDEX 203
# COL 0
# high 10344.3
# open 10343.1
# close 9871.9
# low 9833.9
# position size : 1.0392763981082858
# cash: 88209.0
# entries: 1
#
# INDEX 204
# COL 0
# high 9926.0
# open 9871.8
# close 9759.1
# low 9540.6
# position size : 1.0392763981082858
# cash: 88209.0
# entries: 1
#
# sl update before 204 8487.54
# sl update after at index 204 8783.19
# INDEX 205
# COL 0
# high 10180.0
# open 9759.5
# close 9879.9
# low 9726.6
# position size : 1.0392763981082858
# cash: 88209.0
# entries: 1
#
# INDEX 206
# COL 0
# high 9880.7
# open 9877.2
# close 9832.0
# low 9637.5
# position size : 1.0392763981082858
# cash: 88209.0
# entries: 0
#
# INDEX 207
# COL 0
# high 10179.4
# open 9832.0
# close 9485.5
# low 9337.0
# position size : 1.0392763981082858
# cash: 88209.0
# entries: 0
#
# INDEX 208
# COL 0
# high 9587.1
# open 9475.9
# close 9535.7
# low 9170.0
# position size : 1.0392763981082858
# cash: 88209.0
# entries: 0
#
# INDEX 209
# COL 0
# high 9726.0
# open 9540.4
# close 9503.4
# low 9394.1
# position size : 1.0392763981082858
# cash: 88209.0
# entries: 0
#
# INDEX 210
# COL 0
# high 9705.5
# open 9508.1
# close 9579.0
# low 9404.0
# position size : 1.0392763981082858
# cash: 88209.0
# entries: 0
#
# INDEX 211
# COL 0
# high 10102.0
# open 9579.0
# close 10076.6
# low 9556.9
# position size : 1.0392763981082858
# cash: 88209.0
# entries: 0
#
# INDEX 212
# COL 0
# high 10450.0
# open 10072.8
# close 10353.3
# low 9875.0
# position size : 1.0392763981082858
# cash: 88209.0
# entries: 0
#
# INDEX 213
# COL 0
# high 10675.6
# open 10353.4
# close 10521.1
# low 10290.3
# position size : 1.0392763981082858
# cash: 88209.0
# entries: 0
#
# INDEX 214
# COL 0
# high 10899.1
# open 10518.2
# close 10815.7
# low 10502.2
# position size : 1.0392763981082858
# cash: 88209.0
# entries: 0
#
# INDEX 215
# COL 0
# high 11028.7
# open 10812.3
# close 10933.1
# low 10542.8
# position size : 1.0392763981082858
# cash: 88209.0
# entries: 0
#
# INDEX 216
# COL 0
# high 11931.1
# open 10930.6
# close 11821.7
# low 10930.6
# position size : 1.0392763981082858
# cash: 88209.0
# entries: 0
#
# INDEX 217
# COL 0
# high 12309.3
# open 11826.0
# close 11480.6
# low 11207.2
# position size : 1.0392763981082858
# cash: 88209.0
# entries: 0
#
# sl update before 217 8783.19
# sl update after at index 217 10906.57
# INDEX 218
# COL 0
# high 12158.0
# open 11480.6
# close 11965.7
# low 11388.6
# position size : 1.0392763981082858
# cash: 88209.0
# entries: 0
#
# INDEX 219
# COL 0
# high 12059.6
# open 11965.7
# close 11997.6
# low 11530.5
# position size : 1.0392763981082858
# cash: 88209.0
# entries: 0
#
# INDEX 220
# COL 0
# high 12041.8
# open 11997.6
# close 11877.8
# low 11685.0
# position size : 1.0392763981082858
# cash: 88209.0
# entries: 0
#
# INDEX 221
# COL 0
# high 11972.0
# open 11878.3
# close 11314.0
# low 11268.3
# position size : 1.0392763981082858
# cash: 88209.0
# entries: 0
#
# INDEX 222
# COL 0
# high 11591.5
# open 11314.0
# close 11539.0
# low 11121.6
# position size : 1.0392763981082858
# cash: 88209.0
# entries: 0
#
# INDEX 223
# COL 0
# high 11560.2
# open 11541.6
# close 11396.5
# low 11246.9
# position size : 1.0392763981082858
# cash: 88209.0
# entries: 0
#
# INDEX 224
# COL 0
# high 11442.4
# open 11397.3
# close 10894.4
# low 10790.5
# position size : 1.0392763981082858
# cash: 88209.0
# entries: 0
#
# INDEX 225
# COL 0
# high 10893.8
# open 10889.4
# close 10049.7
# low 9943.9
# position size : 1.0392763981082858
# cash: 88209.0
# entries: 0
#
# sl hit at: 225 10906.57
# return value  Order(size=-inf, price=10906.57, size_type=0, direction=0, fees=0.0, fixed_fees=0.0, slippage=0.0, min_size=0.0, max_size=inf, size_granularity=nan, reject_prob=0.0, lock_cash=False, allow_partial=True, raise_reject=False, log=False)
# INDEX 226
# COL 0
# high 10458.4
# open 10049.1
# close 10293.7
# low 9522.5
# position size : 0.0
# cash: 99543.94078531589
# entries: 1
#
# sl to put in array price: 9264.330000000002
# sl array 9264.330000000002
# long order 226 Order(size=0.1, price=10293.7, size_type=2, direction=0, fees=0.0, fixed_fees=0.0, slippage=0.0, min_size=0.0, max_size=inf, size_granularity=nan, reject_prob=0.0, lock_cash=False, allow_partial=False, raise_reject=True, log=False)
#
# INDEX 227
# COL 0
# high 10520.1
# open 10293.1
# close 10328.3
# low 9774.2
# position size : 0.9670375160080038
# cash: 89589.5467067843
# entries: 1
#
# INDEX 228
# COL 0
# high 10460.6
# open 10328.3
# close 10215.6
# low 10000.0
# position size : 0.9670375160080038
# cash: 89589.5467067843
# entries: 1
#
# INDEX 229
# COL 0
# high 10499.0
# open 10215.6
# close 10308.0
# low 10074.1
# position size : 0.9670375160080038
# cash: 89589.5467067843
# entries: 1
#
# INDEX 230
# COL 0
# high 10948.2
# open 10298.6
# close 10912.2
# low 10255.6
# position size : 0.9670375160080038
# cash: 89589.5467067843
# entries: 1
#
# INDEX 231
# COL 0
# high 10950.6
# open 10913.5
# close 10755.6
# low 10568.3
# position size : 0.9670375160080038
# cash: 89589.5467067843
# entries: 1
#
# INDEX 232
# COL 0
# high 10800.7
# open 10755.6
# close 10140.8
# low 9876.0
# position size : 0.9670375160080038
# cash: 89589.5467067843
# entries: 1
#
# INDEX 233
# COL 0
# high 10234.0
# open 10140.8
# close 10103.1
# low 9756.5
# position size : 0.9670375160080038
# cash: 89589.5467067843
# entries: 1
#
# INDEX 234
# COL 0
# high 10443.6
# open 10103.0
# close 10363.8
# low 10027.0
# position size : 0.9670375160080038
# cash: 89589.5467067843
# entries: 1
#
# INDEX 235
# COL 0
# high 10399.9
# open 10366.4
# close 10133.7
# low 9890.0
# position size : 0.9670375160080038
# cash: 89589.5467067843
# entries: 1
#
# INDEX 236
# COL 0
# high 10329.9
# open 10134.0
# close 10136.2
# low 9915.5
# position size : 0.9670375160080038
# cash: 89589.5467067843
# entries: 1
#
# INDEX 237
# COL 0
# high 10600.0
# open 10136.2
# close 10368.8
# low 10132.3
# position size : 0.9670375160080038
# cash: 89589.5467067843
# entries: 1
#
# INDEX 238
# COL 0
# high 10387.6
# open 10369.8
# close 10184.2
# low 10051.0
# position size : 0.9670375160080038
# cash: 89589.5467067843
# entries: 1
#
# INDEX 239
# COL 0
# high 10288.1
# open 10184.2
# close 9724.5
# low 9602.2
# position size : 0.9670375160080038
# cash: 89589.5467067843
# entries: 1
#
# INDEX 240
# COL 0
# high 9725.1
# open 9722.3
# close 9493.5
# low 9326.0
# position size : 0.9670375160080038
# cash: 89589.5467067843
# entries: 0
#
# INDEX 241
# COL 0
# high 9689.6
# open 9493.6
# close 9578.6
# low 9357.4
# position size : 0.9670375160080038
# cash: 89589.5467067843
# entries: 0
#
# INDEX 242
# COL 0
# high 9681.6
# open 9579.8
# close 9584.4
# low 9430.0
# position size : 0.9670375160080038
# cash: 89589.5467067843
# entries: 0
#
# INDEX 243
# COL 0
# high 9809.0
# open 9585.2
# close 9728.7
# low 9521.7
# position size : 0.9670375160080038
# cash: 89589.5467067843
# entries: 0
#
# INDEX 244
# COL 0
# high 10434.8
# open 9728.0
# close 10339.3
# low 9720.5
# position size : 0.9670375160080038
# cash: 89589.5467067843
# entries: 0
#
# INDEX 245
# COL 0
# high 10762.0
# open 10338.1
# close 10606.9
# low 10270.5
# position size : 0.9670375160080038
# cash: 89589.5467067843
# entries: 0
#
# INDEX 246
# COL 0
# high 10792.3
# open 10605.7
# close 10560.7
# low 10372.0
# position size : 0.9670375160080038
# cash: 89589.5467067843
# entries: 0
#
# INDEX 247
# COL 0
# high 10692.6
# open 10563.2
# close 10564.6
# low 10450.0
# position size : 0.9670375160080038
# cash: 89589.5467067843
# entries: 0
#
# INDEX 248
# COL 0
# high 10900.0
# open 10564.5
# close 10295.9
# low 10181.3
# position size : 0.9670375160080038
# cash: 89589.5467067843
# entries: 0
#
# INDEX 249
# COL 0
# high 10550.0
# open 10295.9
# close 10455.3
# low 10294.2
# position size : 0.9670375160080038
# cash: 89589.5467067843
# entries: 0
#
# INDEX 250
# COL 0
# high 10582.0
# open 10455.4
# close 10384.3
# low 10227.1
# position size : 0.9670375160080038
# cash: 89589.5467067843
# entries: 0
#
# INDEX 251
# COL 0
# high 10480.7
# open 10384.3
# close 10305.4
# low 10069.5
# position size : 0.9670375160080038
# cash: 89589.5467067843
# entries: 0
#
# INDEX 252
# COL 0
# high 10379.5
# open 10304.8
# close 10103.1
# low 9960.0
# position size : 0.9670375160080038
# cash: 89589.5467067843
# entries: 0
#
# INDEX 253
# COL 0
# high 10273.1
# open 10102.3
# close 10157.3
# low 9930.4
# position size : 0.9670375160080038
# cash: 89589.5467067843
# entries: 0
#
# INDEX 254
# COL 0
# high 10430.0
# open 10157.3
# close 10412.5
# low 10038.9
# position size : 0.9670375160080038
# cash: 89589.5467067843
# entries: 0
#
# INDEX 255
# COL 0
# high 10430.0
# open 10412.0
# close 10339.3
# low 10152.5
# position size : 0.9670375160080038
# cash: 89589.5467067843
# entries: 0
#
# INDEX 256
# COL 0
# high 10416.7
# open 10339.3
# close 10334.0
# low 10225.7
# position size : 0.9670375160080038
# cash: 89589.5467067843
# entries: 0
#
# INDEX 257
# COL 0
# high 10359.0
# open 10334.0
# close 10302.1
# low 10245.1
# position size : 0.9670375160080038
# cash: 89589.5467067843
# entries: 0
#
# INDEX 258
# COL 0
# high 10350.0
# open 10301.8
# close 10250.7
# low 10082.5
# position size : 0.9670375160080038
# cash: 89589.5467067843
# entries: 0
#
# INDEX 259
# COL 0
# high 10270.4
# open 10250.9
# close 10187.4
# low 10144.4
# position size : 0.9670375160080038
# cash: 89589.5467067843
# entries: 0
#
# INDEX 260
# COL 0
# high 10255.0
# open 10186.1
# close 10155.5
# low 10100.0
# position size : 0.9670375160080038
# cash: 89589.5467067843
# entries: 0
#
# INDEX 261
# COL 0
# high 10317.5
# open 10155.9
# close 10246.5
# low 9685.0
# position size : 0.9670375160080038
# cash: 89589.5467067843
# entries: 0
#
# INDEX 262
# COL 0
# high 10278.1
# open 10244.4
# close 10169.9
# low 10075.0
# position size : 0.9670375160080038
# cash: 89589.5467067843
# entries: 1
#
# INDEX 263
# COL 0
# high 10177.6
# open 10170.0
# close 9984.9
# low 9910.0
# position size : 0.9670375160080038
# cash: 89589.5467067843
# entries: 1
#
# INDEX 264
# COL 0
# high 10086.5
# open 9984.8
# close 10026.6
# low 9861.1
# position size : 0.9670375160080038
# cash: 89589.5467067843
# entries: 1
#
# INDEX 265
# COL 0
# high 10045.1
# open 10026.5
# close 9704.1
# low 9631.7
# position size : 0.9670375160080038
# cash: 89589.5467067843
# entries: 1
#
# INDEX 266
# COL 0
# high 9790.8
# open 9704.1
# close 8503.8
# low 7844.1
# position size : 0.9670375160080038
# cash: 89589.5467067843
# entries: 0
#
# INDEX 267
# COL 0
# high 8725.8
# open 8501.5
# close 8435.3
# low 8220.1
# position size : 0.9670375160080038
# cash: 89589.5467067843
# entries: 0
#
# sl hit at: 267 9264.330000000002
# return value  Order(size=-inf, price=9264.330000000002, size_type=0, direction=0, fees=0.0, fixed_fees=0.0, slippage=0.0, min_size=0.0, max_size=inf, size_granularity=nan, reject_prob=0.0, lock_cash=False, allow_partial=True, raise_reject=False, log=False)
# INDEX 268
# COL 0
# high 8460.7
# open 8435.1
# close 8062.3
# low 7752.0
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 269
# COL 0
# high 8260.9
# open 8062.3
# close 8178.5
# low 7860.7
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 270
# COL 0
# high 8307.2
# open 8178.2
# close 8199.7
# low 8008.9
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 271
# COL 0
# high 8229.1
# open 8198.8
# close 8041.8
# low 7898.5
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 272
# COL 0
# high 8332.1
# open 8042.6
# close 8287.5
# low 7722.3
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 273
# COL 0
# high 8496.1
# open 8289.1
# close 8288.3
# low 8178.1
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 274
# COL 0
# high 8367.0
# open 8287.5
# close 8353.7
# low 8149.1
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 275
# COL 0
# high 8388.3
# open 8353.9
# close 8221.0
# low 8064.0
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 276
# COL 0
# high 8228.1
# open 8223.6
# close 8132.6
# low 8015.0
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 277
# COL 0
# high 8175.9
# open 8132.9
# close 8126.6
# low 8011.1
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 278
# COL 0
# high 8151.0
# open 8127.2
# close 7850.8
# low 7800.0
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 279
# COL 0
# high 8293.0
# open 7854.9
# close 8185.1
# low 7768.2
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 280
# COL 0
# high 8324.0
# open 8187.2
# close 8167.6
# low 8100.7
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 281
# COL 0
# high 8695.9
# open 8167.8
# close 8561.6
# low 8113.9
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 282
# COL 0
# high 8642.3
# open 8561.6
# close 8555.9
# low 8424.1
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 283
# COL 0
# high 8777.0
# open 8555.9
# close 8256.4
# low 8229.2
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 284
# COL 0
# high 8394.3
# open 8255.8
# close 8299.8
# low 8248.7
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 285
# COL 0
# high 8448.6
# open 8299.9
# close 8273.9
# low 8163.6
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 286
# COL 0
# high 8379.9
# open 8273.9
# close 8345.9
# low 8208.0
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 287
# COL 0
# high 8399.1
# open 8345.8
# close 8160.7
# low 8110.3
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 288
# COL 0
# high 8179.1
# open 8159.3
# close 7995.5
# low 7918.1
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 289
# COL 0
# high 8118.4
# open 7992.6
# close 8069.9
# low 7930.5
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 290
# COL 0
# high 8113.6
# open 8069.9
# close 7946.8
# low 7812.6
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 291
# COL 0
# high 8081.1
# open 7946.8
# close 7951.7
# low 7869.7
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 292
# COL 0
# high 8289.4
# open 7951.7
# close 8217.1
# low 7870.2
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 293
# COL 0
# high 8323.0
# open 8217.1
# close 8195.0
# low 8146.8
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 294
# COL 0
# high 8292.9
# open 8195.0
# close 8023.0
# low 7990.6
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 295
# COL 0
# high 8045.0
# open 8020.1
# close 7465.9
# low 7310.0
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 296
# COL 0
# high 7497.0
# open 7465.9
# close 7412.9
# low 7340.0
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 297
# COL 0
# high 8769.0
# open 7412.9
# close 8654.6
# low 7382.1
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 298
# COL 0
# high 10348.6
# open 8654.7
# close 9233.5
# low 8637.5
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 299
# COL 0
# high 9785.0
# open 9233.4
# close 9525.7
# low 9043.7
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 300
# COL 0
# high 9898.0
# open 9527.1
# close 9203.3
# low 9200.0
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 301
# COL 0
# high 9531.4
# open 9207.6
# close 9404.4
# low 9101.0
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 302
# COL 0
# high 9406.2
# open 9404.4
# close 9154.3
# low 9001.9
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 303
# COL 0
# high 9384.2
# open 9154.1
# close 9141.6
# low 8946.6
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 304
# COL 0
# high 9272.5
# open 9142.7
# close 9226.1
# low 9038.1
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 305
# COL 0
# high 9368.3
# open 9226.0
# close 9287.4
# low 9190.0
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 306
# COL 0
# high 9357.5
# open 9287.5
# close 9194.1
# low 9075.9
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 307
# COL 0
# high 9502.9
# open 9194.6
# close 9394.9
# low 9118.6
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 308
# COL 0
# high 9453.0
# open 9394.8
# close 9308.9
# low 9180.9
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 309
# COL 0
# high 9430.3
# open 9308.7
# close 9335.6
# low 9253.6
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 310
# COL 0
# high 9370.0
# open 9335.7
# close 9214.2
# low 9060.0
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 311
# COL 0
# high 9258.2
# open 9214.3
# close 8774.2
# low 8650.0
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 312
# COL 0
# high 8875.0
# open 8774.2
# close 8808.4
# low 8726.0
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 313
# COL 0
# high 9128.7
# open 8808.9
# close 9033.9
# low 8750.0
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 314
# COL 0
# high 9065.6
# open 9033.8
# close 8734.7
# low 8628.9
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 315
# COL 0
# high 8872.7
# open 8733.9
# close 8812.7
# low 8550.0
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 316
# COL 0
# high 8834.8
# open 8812.7
# close 8776.6
# low 8711.2
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 317
# COL 0
# high 8799.4
# open 8776.7
# close 8645.9
# low 8596.4
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 318
# COL 0
# high 8780.0
# open 8646.0
# close 8470.9
# low 8404.6
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 319
# COL 0
# high 8529.9
# open 8470.9
# close 8490.7
# low 8432.4
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 320
# COL 0
# high 8618.7
# open 8491.1
# close 8500.7
# low 8373.6
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 321
# COL 0
# high 8500.8
# open 8500.7
# close 8188.4
# low 8070.0
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 322
# COL 0
# high 8212.6
# open 8188.4
# close 8131.6
# low 8010.0
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 323
# COL 0
# high 8230.2
# open 8131.9
# close 8095.4
# low 8042.1
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 324
# COL 0
# high 8132.3
# open 8095.5
# close 7626.3
# low 7500.0
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 325
# COL 0
# high 7758.5
# open 7626.3
# close 7265.5
# low 6801.0
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 326
# COL 0
# high 7341.3
# open 7265.2
# close 7310.8
# low 7078.9
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 327
# COL 0
# high 7329.7
# open 7310.6
# close 6898.9
# low 6856.6
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 328
# COL 0
# high 7548.0
# open 6900.4
# close 7109.5
# low 6516.5
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 329
# COL 0
# high 7334.6
# open 7109.6
# close 7155.6
# low 7022.6
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 330
# COL 0
# high 7652.0
# open 7155.5
# close 7508.0
# low 6850.2
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 331
# COL 0
# high 7634.5
# open 7509.3
# close 7419.7
# low 7366.0
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 332
# COL 0
# high 7844.1
# open 7419.0
# close 7739.3
# low 7397.7
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 333
# COL 0
# high 7796.4
# open 7739.5
# close 7544.8
# low 7452.8
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 334
# COL 0
# high 7544.9
# open 7544.9
# close 7391.2
# low 7233.9
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 335
# COL 0
# high 7418.9
# open 7391.1
# close 7294.7
# low 7160.3
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 336
# COL 0
# high 7397.5
# open 7294.6
# close 7291.9
# low 7240.6
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 337
# COL 0
# high 7765.3
# open 7291.9
# close 7197.2
# low 7087.0
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 338
# COL 0
# high 7475.0
# open 7199.4
# close 7387.9
# low 7153.4
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 339
# COL 0
# high 7574.6
# open 7387.4
# close 7529.4
# low 7303.7
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 340
# COL 0
# high 7610.0
# open 7529.2
# close 7488.2
# low 7472.4
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 341
# COL 0
# high 7559.0
# open 7488.3
# close 7508.8
# low 7372.9
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 342
# COL 0
# high 7643.9
# open 7508.8
# close 7342.4
# low 7286.6
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 343
# COL 0
# high 7397.0
# open 7342.4
# close 7226.4
# low 7166.0
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 344
# COL 0
# high 7270.7
# open 7226.5
# close 7214.6
# low 7141.3
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 345
# COL 0
# high 7284.7
# open 7213.8
# close 7199.7
# low 7093.4
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 346
# COL 0
# high 7293.6
# open 7199.7
# close 7258.4
# low 7196.3
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 347
# COL 0
# high 7266.6
# open 7258.5
# close 7066.1
# low 7016.7
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 348
# COL 0
# high 7197.7
# open 7066.2
# close 7118.6
# low 7013.0
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 349
# COL 0
# high 7250.0
# open 7118.5
# close 6892.9
# low 6831.0
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 350
# COL 0
# high 6937.6
# open 6893.0
# close 6622.9
# low 6565.0
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 351
# COL 0
# high 7441.0
# open 6623.1
# close 7275.6
# low 6437.0
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 352
# COL 0
# high 7360.4
# open 7277.4
# close 7149.7
# low 7049.0
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 353
# COL 0
# high 7212.8
# open 7149.8
# close 7186.4
# low 7082.3
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 354
# COL 0
# high 7188.9
# open 7186.5
# close 7133.0
# low 7107.9
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 355
# COL 0
# high 7503.1
# open 7132.9
# close 7499.5
# low 7123.7
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 356
# COL 0
# high 7691.8
# open 7500.2
# close 7320.1
# low 7268.3
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 357
# COL 0
# high 7428.3
# open 7320.2
# close 7258.0
# low 7164.0
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 358
# COL 0
# high 7268.7
# open 7256.5
# close 7202.2
# low 7129.3
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 359
# COL 0
# high 7429.0
# open 7202.3
# close 7203.5
# low 7157.0
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 360
# COL 0
# high 7272.6
# open 7203.5
# close 7254.2
# low 7090.7
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 361
# COL 0
# high 7358.0
# open 7254.8
# close 7313.7
# low 7242.1
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 362
# COL 0
# high 7523.5
# open 7313.8
# close 7391.0
# low 7287.6
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 363
# COL 0
# high 7403.8
# open 7391.0
# close 7245.4
# low 7216.3
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 364
# COL 0
# high 7320.9
# open 7245.4
# close 7196.1
# low 7141.8
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 365
# COL 0
# high 7251.8
# open 7196.2
# close 7200.2
# low 7176.1
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 366
# COL 0
# high 7210.6
# open 7200.3
# close 6964.8
# low 6933.3
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 367
# COL 0
# high 7397.7
# open 6964.8
# close 7346.2
# low 6867.0
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 368
# COL 0
# high 7399.0
# open 7344.6
# close 7355.3
# low 7271.5
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 369
# COL 0
# high 7490.0
# open 7355.9
# close 7359.9
# low 7320.7
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 370
# COL 0
# high 7792.0
# open 7359.7
# close 7758.1
# low 7348.8
# position size : 0.0
# cash: 98548.50137746273
# entries: -1
#
# INDEX 371
# COL 0
# high 8206.4
# open 7758.5
# close 8150.2
# low 7727.9
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 372
# COL 0
# high 8458.0
# open 8150.0
# close 8053.0
# low 7878.4
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 373
# COL 0
# high 8055.6
# open 8053.6
# close 7820.7
# low 7746.4
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 374
# COL 0
# high 8198.3
# open 7820.8
# close 8192.4
# low 7682.0
# position size : 0.0
# cash: 98548.50137746273
# entries: 0
#
# INDEX 375
# COL 0
# high 8282.4
# open 8193.8
# ...
# position size : 0.0
# cash: 118084.22498455252
# entries: -1
#
# INDEX 2064
# COL 0
# high 64479.4
# open 64220.6
# close 62830.1
# low 62816.3
# position size : 0.0
# cash: 118084.22498455252
# entries: -1
#
# INDEX 2065
# COL 0
# high 63218.9
# open 62836.4
# close 59413.9
# low 58000.0
# position size : 0.0
# cash: 118084.22498455252
# entries: -1
#
# INDEX 2066
# COL 0
# high 60230.5
# open 59410.9
# close 59030.3
# low 57862.0
# position size : 0.0
# cash: 118084.22498455252
# entries: -1
#
# INDEX 2067
# COL 0
# high 61160.3
# open 59033.1
# close 59352.0
# low 58708.5
# position size : 0.0
# cash: 118084.22498455252
# entries: -1
#
# INDEX 2068
# COL 0
# high 59950.5
# open 59350.7
# close 59115.0
# low 57679.6
# position size : 0.0
# cash: 118084.22498455252
# entries: -1
#
# INDEX 2069
# COL 0
# high 59454.0
# open 59123.5
# close 58972.6
# low 58745.5
# position size : 0.0
# cash: 118084.22498455252
# entries: -1
#
# INDEX 2070
# COL 0
# high 59074.6
# open 58972.6
# close 57305.7
# low 57200.3
# position size : 0.0
# cash: 118084.22498455252
# entries: -1
#
# INDEX 2071
# COL 0
# high 59424.6
# open 57305.7
# close 59134.6
# low 57133.8
# position size : 0.0
# cash: 118084.22498455252
# entries: -1
#
# INDEX 2072
# COL 0
# high 59811.0
# open 59139.3
# close 57486.0
# low 57415.0
# position size : 0.0
# cash: 118084.22498455252
# entries: -1
#
# INDEX 2073
# COL 0
# high 58520.0
# open 57484.7
# close 57974.6
# low 55602.5
# position size : 0.0
# cash: 118084.22498455252
# entries: -1
#
# INDEX 2074
# COL 0
# high 58328.6
# open 57974.7
# close 56179.5
# low 55636.3
# position size : 0.0
# cash: 118084.22498455252
# entries: -1
#
# INDEX 2075
# COL 0
# high 57007.2
# open 56179.5
# close 53960.3
# low 52550.0
# position size : 0.0
# cash: 118084.22498455252
# entries: -1
#
# INDEX 2076
# COL 0
# high 54842.4
# open 53960.4
# close 54156.0
# low 53756.0
# position size : 0.0
# cash: 118084.22498455252
# entries: -1
#
# INDEX 2077
# COL 0
# high 55307.5
# open 54156.1
# close 54873.1
# low 53630.0
# position size : 0.0
# cash: 118084.22498455252
# entries: -1
#
# INDEX 2078
# COL 0
# high 58091.3
# open 54873.1
# close 57042.0
# low 54596.2
# position size : 0.0
# cash: 118084.22498455252
# entries: -1
#
# INDEX 2079
# COL 0
# high 58044.7
# open 57040.7
# close 57632.5
# low 56387.1
# position size : 0.0
# cash: 118084.22498455252
# entries: -1
#
# INDEX 2080
# COL 0
# high 57980.0
# open 57638.8
# close 57335.9
# low 55564.9
# position size : 0.0
# cash: 118084.22498455252
# entries: -1
#
# INDEX 2081
# COL 0
# high 58566.6
# open 57335.9
# close 58127.9
# low 57316.4
# position size : 0.0
# cash: 118084.22498455252
# entries: -1
#
# INDEX 2082
# COL 0
# high 60624.3
# open 58127.9
# close 60493.9
# low 57638.4
# position size : 0.0
# cash: 118084.22498455252
# entries: -1
#
# INDEX 2083
# COL 0
# high 60609.5
# open 60494.0
# close 59988.0
# low 59397.7
# position size : 0.0
# cash: 118084.22498455252
# entries: -1
#
# INDEX 2084
# COL 0
# high 60385.0
# open 59988.1
# close 59132.0
# low 58680.2
# position size : 0.0
# cash: 118084.22498455252
# entries: -1
#
# INDEX 2085
# COL 0
# high 59203.4
# open 59132.0
# close 58215.0
# low 57489.7
# position size : 0.0
# cash: 118084.22498455252
# entries: -1
#
# INDEX 2086
# COL 0
# high 61328.2
# open 58215.0
# close 60307.7
# low 57622.0
# position size : 0.0
# cash: 118084.22498455252
# entries: -1
#
# INDEX 2087
# COL 0
# high 61777.0
# open 60307.8
# close 61753.5
# low 59187.4
# position size : 0.0
# cash: 118084.22498455252
# entries: -1
#
# INDEX 2088
# COL 0
# high 63850.5
# open 61754.9
# close 62950.4
# low 61566.5
# position size : 0.0
# cash: 118084.22498455252
# entries: -1
#
# INDEX 2089
# COL 0
# high 64130.6
# open 62950.5
# close 63205.5
# low 62348.4
# position size : 0.0
# cash: 118084.22498455252
# entries: -1
#
# INDEX 2090
# COL 0
# high 63550.0
# open 63205.6
# close 63343.5
# low 62757.7
# position size : 0.0
# cash: 118084.22498455252
# entries: -1
#
# INDEX 2091
# COL 0
# high 64000.0
# open 63343.6
# close 63575.9
# low 62362.1
# position size : 0.0
# cash: 118084.22498455252
# entries: -1
#
# INDEX 2092
# COL 0
# high 64753.9
# open 63576.0
# close 63331.4
# low 62566.7
# position size : 0.0
# cash: 118084.22498455252
# entries: -1
#
# INDEX 2093
# COL 0
# high 64691.5
# open 63333.0
# close 64269.7
# low 62711.5
# position size : 0.0
# cash: 118084.22498455252
# entries: -1
#
# INDEX 2094
# COL 0
# high 64817.4
# open 64269.7
# close 63154.4
# low 62948.9
# position size : 0.0
# cash: 118084.22498455252
# entries: -1
#
# INDEX 2095
# COL 0
# high 65819.9
# open 63154.5
# close 65165.5
# low 62666.5
# position size : 0.0
# cash: 118084.22498455252
# entries: 0
#
# INDEX 2096
# COL 0
# high 66575.6
# open 65165.5
# close 65770.8
# low 64814.9
# position size : 0.0
# cash: 118084.22498455252
# entries: 0
#
# INDEX 2097
# COL 0
# high 66257.6
# open 65771.9
# close 65841.0
# low 65422.1
# position size : 0.0
# cash: 118084.22498455252
# entries: 0
#
# INDEX 2098
# COL 0
# high 66074.7
# open 65842.5
# close 65598.0
# low 65431.9
# position size : 0.0
# cash: 118084.22498455252
# entries: 0
#
# INDEX 2099
# COL 0
# high 65608.5
# open 65599.5
# close 63330.0
# low 62850.0
# position size : 0.0
# cash: 118084.22498455252
# entries: 0
#
# INDEX 2100
# COL 0
# high 64118.7
# open 63328.6
# close 60816.0
# low 60158.9
# position size : 0.0
# cash: 118084.22498455252
# entries: 0
#
# INDEX 2101
# COL 0
# high 62388.5
# open 60814.6
# close 60651.4
# low 59989.0
# position size : 0.0
# cash: 118084.22498455252
# entries: 0
#
# INDEX 2102
# COL 0
# high 61475.5
# open 60651.0
# close 60750.0
# low 59869.0
# position size : 0.0
# cash: 118084.22498455252
# entries: 0
#
# INDEX 2103
# COL 0
# high 62477.0
# open 60750.0
# close 62086.5
# low 60468.1
# position size : 0.0
# cash: 118084.22498455252
# entries: 0
#
# INDEX 2104
# COL 0
# high 62367.9
# open 62086.6
# close 62064.1
# low 61689.0
# position size : 0.0
# cash: 118084.22498455252
# entries: 0
#
# INDEX 2105
# COL 0
# high 62978.7
# open 62064.1
# close 62819.4
# low 61818.0
# position size : 0.0
# cash: 118084.22498455252
# entries: 0
#
# INDEX 2106
# COL 0
# high 64460.3
# open 62819.4
# close 62223.2
# low 62136.1
# position size : 0.0
# cash: 118084.22498455252
# entries: 0
#
# INDEX 2107
# COL 0
# high 63197.5
# open 62223.1
# close 62163.4
# low 61870.2
# position size : 0.0
# cash: 118084.22498455252
# entries: 0
#
# INDEX 2108
# COL 0
# high 62545.3
# open 62163.4
# close 60638.5
# low 60306.1
# position size : 0.0
# cash: 118084.22498455252
# entries: 0
#
# INDEX 2109
# COL 0
# high 61318.1
# open 60637.6
# close 60319.5
# low 58932.1
# position size : 0.0
# cash: 118084.22498455252
# entries: 0
#
# INDEX 2110
# COL 0
# high 63418.3
# open 60319.5
# close 62533.9
# low 60086.3
# position size : 0.0
# cash: 118084.22498455252
# entries: 0
#
# INDEX 2111
# COL 0
# high 63485.8
# open 62533.9
# close 63204.1
# low 62487.4
# position size : 0.0
# cash: 118084.22498455252
# entries: 0
#
# INDEX 2112
# COL 0
# high 63287.9
# open 63204.1
# close 62872.3
# low 62054.8
# position size : 0.0
# cash: 118084.22498455252
# entries: 0
#
# INDEX 2113
# COL 0
# high 66525.5
# open 62872.4
# close 66087.0
# low 62465.5
# position size : 0.0
# cash: 118084.22498455252
# entries: 0
#
# INDEX 2114
# COL 0
# high 67950.9
# open 66087.0
# close 67071.6
# low 64800.0
# position size : 0.0
# cash: 118084.22498455252
# entries: 0
#
# INDEX 2115
# COL 0
# high 68418.8
# open 67071.7
# close 67618.2
# low 66751.5
# position size : 0.0
# cash: 118084.22498455252
# entries: 0
#
# INDEX 2116
# COL 0
# high 67940.0
# open 67618.2
# close 67424.5
# low 66683.3
# position size : 0.0
# cash: 118084.22498455252
# entries: 0
#
# INDEX 2117
# COL 0
# high 69000.0
# open 67424.4
# close 68426.7
# low 67191.5
# position size : 0.0
# cash: 118084.22498455252
# entries: 0
#
# INDEX 2118
# COL 0
# high 68697.0
# open 68427.0
# close 68378.0
# low 68010.0
# position size : 0.0
# cash: 118084.22498455252
# entries: 0
#
# INDEX 2119
# COL 0
# high 69388.0
# open 68378.8
# close 69034.5
# low 68096.4
# position size : 0.0
# cash: 118084.22498455252
# entries: 1
#
# sl to put in array price: 62131.05
# sl array 62131.05
# long order 2119 Order(size=0.1, price=69034.5, size_type=2, direction=0, fees=0.0, fixed_fees=0.0, slippage=0.0, min_size=0.0, max_size=inf, size_granularity=nan, reject_prob=0.0, lock_cash=False, allow_partial=False, raise_reject=True, log=False)
#
# INDEX 2120
# COL 0
# high 69537.1
# open 69034.6
# close 67375.5
# low 66849.6
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2121
# COL 0
# high 67832.9
# open 67375.5
# close 67419.8
# low 66564.0
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2122
# COL 0
# high 67464.5
# open 67423.3
# close 66665.0
# low 65257.1
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2123
# COL 0
# high 68850.7
# open 66665.0
# close 68200.0
# low 66508.2
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2124
# COL 0
# high 68765.5
# open 68200.0
# close 66696.8
# low 65596.4
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2125
# COL 0
# high 67456.6
# open 66696.2
# close 67094.7
# low 66441.4
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2126
# COL 0
# high 68333.0
# open 67094.7
# close 68021.8
# low 66934.3
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2127
# COL 0
# high 70282.9
# open 68021.8
# close 69961.4
# low 67620.8
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2128
# COL 0
# high 73640.5
# open 69961.5
# close 72735.5
# low 69762.3
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2129
# COL 0
# high 72953.7
# open 72735.6
# close 72345.6
# low 71430.4
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2130
# COL 0
# high 72683.5
# open 72345.7
# close 70298.2
# low 69674.9
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2131
# COL 0
# high 71626.9
# open 70298.2
# close 69495.2
# low 68823.5
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2132
# COL 0
# high 69909.0
# open 69495.1
# close 69376.8
# low 69020.0
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2133
# COL 0
# high 69391.7
# open 69376.8
# close 68771.5
# low 67474.7
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2134
# COL 0
# high 69494.9
# open 68776.1
# close 67857.2
# low 66835.1
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2135
# COL 0
# high 70540.1
# open 67857.1
# close 69374.9
# low 67478.6
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2136
# COL 0
# high 76407.1
# open 69374.9
# close 75581.7
# low 69295.0
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2137
# COL 0
# high 76830.0
# open 75581.8
# close 75865.4
# low 74427.1
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2138
# COL 0
# high 77175.2
# open 75865.4
# close 76506.9
# low 75591.5
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2139
# COL 0
# high 76913.0
# open 76506.9
# close 76684.1
# low 75715.7
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2140
# COL 0
# high 81498.1
# open 76684.1
# close 80359.5
# low 76362.3
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2141
# COL 0
# high 89526.3
# open 80359.5
# close 88637.1
# low 80208.3
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# sl update before 2141 62131.05
# sl update after at index 2141 79773.39000000001
# INDEX 2142
# COL 0
# high 89922.2
# open 88637.2
# close 87936.9
# low 85068.0
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2143
# COL 0
# high 93242.1
# open 87936.9
# close 90375.4
# low 86129.9
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2144
# COL 0
# high 91779.2
# open 90375.4
# close 87322.4
# low 86677.3
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2145
# COL 0
# high 91848.8
# open 87326.9
# close 91042.3
# low 87077.8
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2146
# COL 0
# high 91918.7
# open 91028.1
# close 90573.2
# low 90074.8
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2147
# COL 0
# high 91455.2
# open 90583.2
# close 89854.2
# low 88650.0
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2148
# COL 0
# high 92600.0
# open 89854.3
# close 90465.7
# low 89369.4
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2149
# COL 0
# high 93912.0
# open 90465.7
# close 92292.1
# low 90351.8
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2150
# COL 0
# high 94819.5
# open 92292.2
# close 94285.0
# low 91474.8
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2151
# COL 0
# high 98924.7
# open 94289.0
# close 98317.0
# low 94038.1
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# sl update before 2151 79773.39000000001
# sl update after at index 2151 88485.3
# INDEX 2152
# COL 0
# high 99595.0
# open 98317.0
# close 98891.4
# low 97017.5
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2153
# COL 0
# high 98909.8
# open 98891.5
# close 97684.1
# low 97130.0
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2154
# COL 0
# high 98570.5
# open 97684.1
# close 97891.9
# low 95747.0
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2155
# COL 0
# high 98896.2
# open 97903.7
# close 92999.0
# low 92573.9
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2156
# COL 0
# high 94981.4
# open 92999.1
# close 91958.3
# low 90801.9
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2157
# COL 0
# high 97192.1
# open 91958.3
# close 95854.3
# low 91797.5
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2158
# COL 0
# high 96564.7
# open 95854.3
# close 95642.3
# low 94535.8
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2159
# COL 0
# high 98609.0
# open 95642.3
# close 97458.0
# low 95352.9
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2160
# COL 0
# high 97466.2
# open 97458.1
# close 96395.3
# low 96088.0
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2161
# COL 0
# high 97897.9
# open 96395.2
# close 97185.7
# low 95700.0
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2162
# COL 0
# high 98157.0
# open 97185.7
# close 95826.8
# low 94379.2
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2163
# COL 0
# high 96300.0
# open 95826.8
# close 95845.3
# low 93575.0
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2164
# COL 0
# high 99008.9
# open 95845.2
# close 98618.3
# low 94580.7
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2165
# COL 0
# high 104087.7
# open 98602.4
# close 96927.3
# low 90606.3
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2166
# COL 0
# high 101900.0
# open 96927.4
# close 99729.4
# low 96228.6
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2167
# COL 0
# high 100582.4
# open 99729.4
# close 99832.6
# low 98823.6
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2168
# COL 0
# high 101359.3
# open 99832.6
# close 101106.5
# low 98669.6
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2169
# COL 0
# high 101211.1
# open 101106.6
# close 97272.9
# low 93867.2
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2170
# COL 0
# high 98266.3
# open 97273.0
# close 96582.1
# low 94250.1
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2171
# COL 0
# high 101876.3
# open 96582.2
# close 101110.4
# low 95634.2
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2172
# COL 0
# high 102525.0
# open 101116.9
# close 100002.9
# low 99307.1
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2173
# COL 0
# high 101900.0
# open 100002.9
# close 101413.2
# low 99202.7
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2174
# COL 0
# high 102648.2
# open 101413.2
# close 101418.8
# low 100606.2
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2175
# COL 0
# high 105216.6
# open 101418.8
# close 104469.1
# low 101232.6
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2176
# COL 0
# high 107803.7
# open 104469.1
# close 106060.3
# low 103332.5
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# INDEX 2177
# COL 0
# high 108384.6
# open 106060.3
# close 106894.3
# low 105652.8
# position size : 0.17105103243241065
# cash: 106275.80248609727
# entries: 1
#
# sl update before 2177 88485.3
# sl update after at index 2177 96204.87000000001
# Total Return: 0.2456018286223709
#
# Order Records:
