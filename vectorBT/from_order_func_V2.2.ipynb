# %%
import pandas as pd
import numpy as np
import vectorbt as vbt
from datetime import datetime
import os 
from numba import njit
from vectorbt.portfolio.enums import Direction, SizeType

# Function to download and save data
def download_and_save_data(symbol, file_name, overwrite=False):
    joined = os.path.join(dir_name, file_name)
    if os.path.exists(joined) and not overwrite:
        data = pd.read_pickle(joined)
        print(f'File {file_name} exists already')
    else:
        data = vbt.CCXTData.download(exchange='kucoin', symbols=symbol, timeframe='1d', start=start, end=end).get()
        data.to_pickle(joined)
        print(f'Downloaded and saved {symbol} data')
    return data
# Out:
# /Users/andre/Documents/Python/trading_clone_singapore_DO/trading_singapore_digitalocean/pandas/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# Prepare data
start = '2019-01-01 UTC'  # crypto is in UTC
end = datetime.utcnow()
dir_name = '/Users/andre/Documents/Python/trading_clone_singapore_DO/trading_singapore_digitalocean/vectorBT'
os.makedirs(dir_name, exist_ok=True)


# Download BTC data
btc_price = download_and_save_data('BTC/USDT', 'btc_price_1d.pkl', overwrite=False)
btc_price.head()

# Download ETH data
eth_price = download_and_save_data('ETH/USDT', 'eth_price_1d.pkl', overwrite=False)

# Align the DataFrames by their index
btc_price_aligned, eth_price_aligned = btc_price.align(eth_price, join='inner')

# Concatenate the aligned DataFrames
comb_price = pd.concat([btc_price_aligned, eth_price_aligned], axis=1, keys=['BTC', 'ETH'])
comb_price.columns.names = ['symbol', 'attribute']

# Create DataFrames for Open, High, Low, and Close prices
comb_open = pd.concat([btc_price_aligned['Open'], eth_price_aligned['Open']], axis=1, keys=['btc_open', 'eth_open'])
comb_high = pd.concat([btc_price_aligned['High'], eth_price_aligned['High']], axis=1, keys=['btc_high', 'eth_high'])
comb_low = pd.concat([btc_price_aligned['Low'], eth_price_aligned['Low']], axis=1, keys=['btc_low', 'eth_low'])
comb_close = pd.concat([btc_price_aligned['Close'], eth_price_aligned['Close']], axis=1, keys=['btc_close', 'eth_close'])

# Display the resulting DataFrames
print("Open Prices:")
print(comb_open.head())

print("\nHigh Prices:")
print(comb_high.head())

print("\nLow Prices:")
print(comb_low.head())

print("\nClose Prices:")
print(comb_close.head())
# Out:
# File btc_price_1d.pkl exists already
# File eth_price_1d.pkl exists already
# Open Prices:
#                               btc_open    eth_open
# Open time
# 2019-01-01 00:00:00+00:00  3700.170853  131.361407
# 2019-01-02 00:00:00+00:00  3799.644687  139.098781
# 2019-01-03 00:00:00+00:00  3857.633097  152.009074
# 2019-01-04 00:00:00+00:00  3767.854300  146.145033
# 2019-01-05 00:00:00+00:00  3789.000000  152.536302
#
# High Prices:
#                               btc_high    eth_high
# Open time
# 2019-01-01 00:00:00+00:00  3805.841739  139.826115
# 2019-01-02 00:00:00+00:00  3880.257733  155.000000
# 2019-01-03 00:00:00+00:00  3862.600830  153.584211
# 2019-01-04 00:00:00+00:00  3821.195343  154.700000
# 2019-01-05 00:00:00+00:00  3838.674540  158.871870
#
# Low Prices:
#                                btc_low     eth_low
# Open time
# 2019-01-01 00:00:00+00:00  3645.525763  130.082442
# 2019-01-02 00:00:00+00:00  3750.000001  137.734799
# 2019-01-03 00:00:00+00:00  3728.917225  143.277125
# 2019-01-04 00:00:00+00:00  3706.000000  144.336355
# 2019-01-05 00:00:00+00:00  3756.410862  152.000000
#
# Close Prices:
#                              btc_close   eth_close
# Open time
# 2019-01-01 00:00:00+00:00  3799.644687  138.909351
# 2019-01-02 00:00:00+00:00  3856.504318  152.004189
# 2019-01-03 00:00:00+00:00  3765.999334  146.244850
# 2019-01-04 00:00:00+00:00  3791.461260  152.575004
# 2019-01-05 00:00:00+00:00  3772.156039  152.831518

# %% [markdown]
# ## ma cross overall trend prediction

# %%
def ma_cross_rsi(close_price, ma1_window, ma2_window, ma3_window, ma4_window, ma5_window, rsi_buy_threshold, rsi_sell_threshold):
    # Calculate moving averages
    ma1 = vbt.MA.run(close_price, window=ma1_window).ma.to_numpy()
    ma2 = vbt.MA.run(close_price, window=ma2_window).ma.to_numpy()
    ma3 = vbt.MA.run(close_price, window=ma3_window).ma.to_numpy()
    ma4 = vbt.MA.run(close_price, window=ma4_window).ma.to_numpy()
    ma5 = vbt.MA.run(close_price, window=ma5_window).ma.to_numpy()
    
    # Determine slow trend direction
    slow_trend_up = (ma4 > ma5)
    slow_trend_down = (ma4 < ma5)

    # Determine short trend direction
    short_trend_up = (ma1 > ma2) & (ma2 > ma3)
    short_trend_undecided = (ma1 < ma2) & (ma2 > ma3)
    short_trend_down = (ma1 < ma2) & (ma2 < ma3)

    # Calculate RSI and determine buy/sell signals
    rsi = vbt.RSI.run(close_price, window=14).rsi.to_numpy()
    rsi_buy = rsi > rsi_buy_threshold
    rsi_sell = rsi < rsi_sell_threshold
    
    # Generate buy and sell signals
    signal_buy = slow_trend_up & short_trend_up & rsi_buy
    signal_sell = slow_trend_down & short_trend_down & rsi_sell

    # Define caution signals for long and short positions
    no_caution_long = slow_trend_up & short_trend_up
    caution_long1 = slow_trend_up & short_trend_undecided 
    caution_long2 = slow_trend_up & short_trend_down

    no_caution_short = slow_trend_down & short_trend_down
    caution_short1 = slow_trend_down & short_trend_undecided
    caution_short2 = slow_trend_down & short_trend_up

    # Define conditions and corresponding values for signals
    conditions = [
        signal_buy,
        no_caution_long,
        caution_long1,
        caution_long2,
        signal_sell,
        no_caution_short,
        caution_short1,
        caution_short2
    ]

    values = [
        100,  # Strong buy signal (slow trend up, short trend up, and RSI above the buy threshold)
        75,   # No caution long (slow trend up and short trend up)
        50,   # Caution long 1 (slow trend up and short trend undecided)
        25,   # Caution long 2 (slow trend up and short trend down)
        -100, # Strong sell signal (slow trend down, short trend down, and RSI below the sell threshold)
        -75,  # No caution short (slow trend down and short trend down)
        -50,  # Caution short 1 (slow trend down and short trend undecided)
        -25   # Caution short 2 (slow trend down and short trend up)
    ]

    # Use np.select to apply the conditions and assign the corresponding values
    signal = np.select(conditions, values, default=0)  # 0: No signal (default value when none of the conditions are met)

    return signal

# Create the indicator factory
ma_cross_slow = vbt.IndicatorFactory(
    class_name='MA_Cross_rsi',
    short_name='ma_c_slow',
    input_names=['Close'],
    param_names=['ma1', 'ma2', 'ma3', 'ma4', 'ma5', 'rsi_buy_threshold', 'rsi_sell_threshold'],
    output_names=['ma_cross_rsi']
).from_apply_func(ma_cross_rsi, ma1=20, ma2=30, ma3=40, ma4=125, ma5=150, rsi_buy_threshold=70, rsi_sell_threshold=30)

# Define window sizes and RSI thresholds
ma_trend_fast = 50
ma_trend_mid = 100
ma_trend_slow = 150

ma_slow_trend1 = 400
ma_slow_trend_2 = 500

rsi_buy_threshold = 70
rsi_sell_threshold = 30

# Run the indicator
trend = ma_cross_slow.run(
    comb_close,
    ma1=ma_trend_fast,
    ma2=ma_trend_mid,
    ma3=ma_trend_slow,
    ma4=ma_slow_trend1,
    ma5=ma_slow_trend_2,
    rsi_buy_threshold=rsi_buy_threshold,
    rsi_sell_threshold=rsi_sell_threshold,
    param_product=True
)

# Display the first 150 rows of the signal output
trend.ma_cross_rsi.head(150)
# Out:
# ma_c_slow_ma1                       50
# ma_c_slow_ma2                      100
# ma_c_slow_ma3                      150
# ma_c_slow_ma4                      400
# ma_c_slow_ma5                      500
# ma_c_slow_rsi_buy_threshold         70
# ma_c_slow_rsi_sell_threshold        30
#                              btc_close eth_close
# Open time
# 2019-01-01 00:00:00+00:00            0         0
# 2019-01-02 00:00:00+00:00            0         0
# 2019-01-03 00:00:00+00:00            0         0
# 2019-01-04 00:00:00+00:00            0         0
# 2019-01-05 00:00:00+00:00            0         0
# ...                                ...       ...
# 2019-05-26 00:00:00+00:00            0         0
# 2019-05-27 00:00:00+00:00            0         0
# 2019-05-28 00:00:00+00:00            0         0
# 2019-05-29 00:00:00+00:00            0         0
# 2019-05-30 00:00:00+00:00            0         0
#
# [150 rows x 2 columns]

# %%
# Numba-compiled order function
@njit
def order_func_nb(c, high, low, open_, entries, sl_prices):
    close_price = c.close[c.i, c.col]
    low_price = low[c.i, c.col]
    high_price = high[c.i, c.col]
    open_price = open_[c.i, c.col]    
    print("INDEX", c.i)
    print("COL", c.col)
    print('close price:', close_price)
    print('high price:', high_price)
    print('low price:', low_price)
    print('open price:', open_price)
    print('position size :', c.position_now)
    print('cash:', c.cash_now)
    print('entries:', entries[c.i, c.col])
    print()

# if in position 
    if (c.position_now > 0):
        # Check if SL is hit
        if low[c.i-1,c.col] <= sl_prices[c.i]:
            value = vbt.portfolio.nb.order_nb(
                size=-np.inf,  # Close position
                price=sl_prices[c.i],
                size_type=SizeType.Amount,
                direction=Direction.LongOnly)

            print('sl hit at Index:', c.i-1)
            print('sl price:', sl_prices[c.i])
            return value
        
        # check condition to adjust sl 
        # find lowest low in the last 5 bars
        # set sl n% lower than the lowest low
        # if new sl is higher than the current sl update
        # if new sl is lower than the current sl do nothing

        # sl update for long position
        if c.i >= 5:  # Ensure there are enough bars to look back
            lowest_low = np.min(low[c.i-2:c.i,c.col])  # Find the lowest low in the last 5 bars
            if (entries[c.i, c.col] == 75):
                print('sl update before',c.i,sl_prices[c.i])
                update1 = lowest_low * 0.90
                if update1 > sl_prices[c.i]:
                    sl_prices[:]= update1
                    print('sl update after at index',c.i,sl_prices[c.i])
            if (entries[c.i, c.col] == 50):  
                update2 = lowest_low * 0.95
                if update2 > sl_prices[c.i]:
                    print('sl update before',c.i,sl_prices[c.i])
                    sl_prices[:]= update2          
                print('sl update after at index',c.i,sl_prices[c.i])
            if (entries[c.i, c.col] == 25):
                update3 = lowest_low * 0.98
                if update3 > sl_prices[c.i]:
                    print('sl update before',c.i,sl_prices[c.i])
                    update3 = lowest_low * 0.98
                print('sl update after at index',c.i,sl_prices[c.i])

    # if not in position search for position to enter
    elif (c.position_now == 0) & (c.i != 0):
        if entries[c.i, c.col] == 100:
            sl_price = close_price * 0.90
            order = vbt.portfolio.nb.order_nb(
                size=0.1,  # Adjusted order size
                price=close_price,  # Current closing price
                size_type=SizeType.Percent,  # Specify size type
                direction=Direction.LongOnly,  # Long-only trading
                fees=0.0,  # No fees
                slippage=0.0,  # No slippage
                allow_partial=False,  # Do not allow partial fills
                raise_reject=True  # Raise an error if the order is rejected
            )
            sl_prices[:] = sl_price 
            print('sl to put in array price:', sl_price)
            print('sl array',sl_prices[1])   # Save the SL price using a single index
            print('long order', c.i,order)
            print()
            return order
    


    return vbt.portfolio.enums.NoOrder


open_ = comb_open.to_numpy()
high = comb_high.to_numpy()
low = comb_low.to_numpy()
close = comb_close
entries = trend.ma_cross_rsi.to_numpy()

# Create an array to store SL prices
sl_prices = np.full(close.shape[0], np.nan)  # Use a 1D array
# Create portfolio
pf = vbt.Portfolio.from_order_func(
    close,           # Price DataFrame
    order_func_nb,
    high,
    low,
    open_,
    entries,    # Order function
    sl_prices,  # Pass the SL prices array
    init_cash=100000,  # Initial cash balance
)

# Display some portfolio performance metrics
print("Total Return:", pf.total_return())
print("\nOrder Records:")

pf.orders.records_readable

# Optional: Plot equity curve
# pf.plot().show()
# Out:
# INDEX 0
# COL 0
# close price: 3799.644687
# high price: 3805.841739
# low price: 3645.525763
# open price: 3700.170853
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 1
# COL 0
# close price: 3856.504318
# high price: 3880.257733
# low price: 3750.000001
# open price: 3799.644687
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 2
# COL 0
# close price: 3765.999334
# high price: 3862.60083
# low price: 3728.917225
# open price: 3857.633097
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 3
# COL 0
# close price: 3791.46126
# high price: 3821.195343
# low price: 3706.0
# open price: 3767.8543
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 4
# COL 0
# close price: 3772.156039
# high price: 3838.67454
# low price: 3756.410862
# open price: 3789.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 5
# COL 0
# close price: 3988.471816
# high price: 4023.0
# low price: 3746.584563
# open price: 3775.703265
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 6
# COL 0
# close price: 3972.264189
# high price: 4017.71888
# low price: 3927.799365
# open price: 3984.865903
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 7
# COL 0
# close price: 3956.635321
# high price: 4061.280555
# low price: 3925.0
# open price: 3977.721738
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 8
# COL 0
# close price: 3967.16117
# high price: 3999.999999
# low price: 3940.0
# open price: 3953.740659
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 9
# COL 0
# close price: 3582.995912
# high price: 3995.174297
# low price: 3538.410921
# open price: 3962.210833
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 10
# COL 0
# close price: 3601.765191
# high price: 3647.694494
# low price: 3532.298156
# open price: 3582.670179
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 11
# COL 0
# close price: 3588.336328
# high price: 3615.341123
# low price: 3536.275592
# open price: 3601.765191
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 12
# COL 0
# close price: 3470.442417
# high price: 3620.330298
# low price: 3446.953248
# open price: 3586.944215
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 13
# COL 0
# close price: 3625.940976
# high price: 3668.902955
# low price: 3465.964471
# open price: 3477.754986
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 14
# COL 0
# close price: 3558.825309
# high price: 3644.873222
# low price: 3523.408177
# open price: 3621.054803
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 15
# COL 0
# close price: 3585.539637
# high price: 3637.545485
# low price: 3544.18794
# open price: 3553.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 16
# COL 0
# close price: 3613.059078
# high price: 3629.854475
# low price: 3536.929827
# open price: 3590.559117
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 17
# COL 0
# close price: 3598.563462
# high price: 3621.231797
# low price: 3569.950664
# open price: 3621.231797
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 18
# COL 0
# close price: 3669.514623
# high price: 3713.263735
# low price: 3592.39684
# open price: 3606.551267
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 19
# COL 0
# close price: 3541.961501
# high price: 3694.320724
# low price: 3482.0
# open price: 3666.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 20
# COL 0
# close price: 3528.160647
# high price: 3556.419913
# low price: 3491.426433
# open price: 3540.956207
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 21
# COL 0
# close price: 3573.882315
# high price: 3602.428923
# low price: 3448.0
# open price: 3525.618845
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 22
# COL 0
# close price: 3553.668236
# high price: 3605.0
# low price: 3516.745198
# open price: 3570.777944
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 23
# COL 0
# close price: 3565.610748
# high price: 3585.98651
# low price: 3526.756089
# open price: 3548.001237
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 24
# COL 0
# close price: 3571.590258
# high price: 3577.898931
# low price: 3520.682464
# open price: 3567.534218
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 25
# COL 0
# close price: 3564.413089
# high price: 3653.931361
# low price: 3549.796545
# open price: 3566.918941
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 26
# COL 0
# close price: 3556.026201
# high price: 3581.399326
# low price: 3500.496895
# open price: 3564.41309
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 27
# COL 0
# close price: 3439.084664
# high price: 3559.997922
# low price: 3385.98654
# open price: 3548.928346
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 28
# COL 0
# close price: 3416.423082
# high price: 3445.666304
# low price: 3352.150773
# open price: 3432.386812
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 29
# COL 0
# close price: 3465.360373
# high price: 3479.461934
# low price: 3380.00245
# open price: 3407.693594
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 30
# COL 0
# close price: 3435.476794
# high price: 3494.64171
# low price: 3418.681646
# open price: 3460.586454
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 31
# COL 0
# close price: 3464.166444
# high price: 3482.323556
# low price: 3400.0
# open price: 3435.406627
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 32
# COL 0
# close price: 3505.695874
# high price: 3518.937773
# low price: 3436.516682
# open price: 3464.166444
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 33
# COL 0
# close price: 3455.166043
# high price: 3505.695874
# low price: 3427.031206
# open price: 3505.695874
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 34
# COL 0
# close price: 3459.109573
# high price: 3485.0
# low price: 3430.000256
# open price: 3457.256026
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 35
# COL 0
# close price: 3466.120649
# high price: 3479.991522
# low price: 3445.000006
# open price: 3457.280468
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 36
# COL 0
# close price: 3402.988749
# high price: 3480.553146
# low price: 3382.197503
# open price: 3472.822004
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 37
# COL 0
# close price: 3395.393984
# high price: 3426.221983
# low price: 3390.001002
# open price: 3402.988751
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 38
# COL 0
# close price: 3660.0
# high price: 3731.534384
# low price: 3379.005494
# open price: 3393.342918
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 39
# COL 0
# close price: 3660.272053
# high price: 3675.98
# low price: 3626.210808
# open price: 3660.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 40
# COL 0
# close price: 3682.697181
# high price: 3687.704134
# low price: 3613.567539
# open price: 3668.137816
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 41
# COL 0
# close price: 3621.279969
# high price: 3666.331161
# low price: 3615.752931
# open price: 3666.331161
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 42
# COL 0
# close price: 3632.008858
# high price: 3660.0
# low price: 3580.182806
# open price: 3644.976124
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 43
# COL 0
# close price: 3609.000011
# high price: 3663.82986
# low price: 3592.000009
# open price: 3632.924018
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 44
# COL 0
# close price: 3589.999998
# high price: 3627.672075
# low price: 3570.961155
# open price: 3609.000003
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 45
# COL 0
# close price: 3595.83462
# high price: 3650.0
# low price: 3571.787184
# open price: 3589.999998
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 46
# COL 0
# close price: 3615.410002
# high price: 3649.206298
# low price: 3595.603349
# open price: 3596.969796
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 47
# COL 0
# close price: 3665.246462
# high price: 3698.059545
# low price: 3605.5
# open price: 3615.41
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 48
# COL 0
# close price: 3881.0
# high price: 3900.0
# low price: 3660.284026
# open price: 3674.999999
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 49
# COL 0
# close price: 3913.0
# high price: 3992.148135
# low price: 3802.00000001
# open price: 3881.00000001
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 50
# COL 0
# close price: 3974.99139506
# high price: 4050.0
# low price: 3870.354929
# open price: 3910.50002727
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 51
# COL 0
# close price: 3937.647732
# high price: 4013.75503992
# low price: 3900.55121299
# open price: 3973.126369
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 52
# COL 0
# close price: 3971.746659
# high price: 3985.52778809
# low price: 3928.96279679
# open price: 3939.999999
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 53
# COL 0
# close price: 4112.900968
# high price: 4158.08648551
# low price: 3934.81928255
# open price: 3959.14205667
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 54
# COL 0
# close price: 3750.6507972
# high price: 4198.47174203
# low price: 3714.32708055
# open price: 4112.900968
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 55
# COL 0
# close price: 3830.95429929
# high price: 3870.0
# low price: 3748.211143
# open price: 3748.211143
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 56
# COL 0
# close price: 3810.2960346
# high price: 3849.999992
# low price: 3785.00000611
# open price: 3824.986869
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 57
# COL 0
# close price: 3816.3
# high price: 3835.24660653
# low price: 3690.0
# open price: 3810.79603462
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 58
# COL 0
# close price: 3816.1300759
# high price: 3885.0
# low price: 3775.8066242
# open price: 3814.01549251
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 59
# COL 0
# close price: 3821.6
# high price: 3870.0
# low price: 3810.05341961
# open price: 3816.1300759
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 60
# COL 0
# close price: 3824.1
# high price: 3841.5
# low price: 3757.0
# open price: 3821.6
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 61
# COL 0
# close price: 3805.8
# high price: 3839.1
# low price: 3781.1
# open price: 3822.3
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 62
# COL 0
# close price: 3714.4
# high price: 3826.7
# low price: 3679.8
# open price: 3806.2
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 63
# COL 0
# close price: 3855.0
# high price: 3877.6
# low price: 3702.9
# open price: 3723.2
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 64
# COL 0
# close price: 3861.2
# high price: 3889.0
# low price: 3810.0
# open price: 3855.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 65
# COL 0
# close price: 3869.9
# high price: 3904.9
# low price: 3845.0
# open price: 3862.7
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 66
# COL 0
# close price: 3864.7
# high price: 3932.3
# low price: 3802.0
# open price: 3873.9
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 67
# COL 0
# close price: 3942.3
# high price: 3966.6
# low price: 3856.2
# open price: 3863.5
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 68
# COL 0
# close price: 3915.6
# high price: 3940.3
# low price: 3885.0
# open price: 3940.1
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 69
# COL 0
# close price: 3874.4
# high price: 3935.4
# low price: 3840.2
# open price: 3915.1
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 70
# COL 0
# close price: 3882.4
# high price: 3909.2
# low price: 3815.1
# open price: 3872.2
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 71
# COL 0
# close price: 3866.8
# high price: 3896.8
# low price: 3840.7
# open price: 3885.8
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 72
# COL 0
# close price: 3878.7
# high price: 3920.0
# low price: 3815.7
# open price: 3863.2
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 73
# COL 0
# close price: 3922.3
# high price: 3935.0
# low price: 3874.5
# open price: 3878.7
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 74
# COL 0
# close price: 4002.0
# high price: 4050.0
# low price: 3919.3
# open price: 3923.6
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 75
# COL 0
# close price: 3978.8
# high price: 4006.9
# low price: 3953.4
# open price: 4002.1
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 76
# COL 0
# close price: 3986.7
# high price: 4035.0
# low price: 3954.1
# open price: 3978.9
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 77
# COL 0
# close price: 4012.9
# high price: 4028.2
# low price: 3968.7
# open price: 3987.1
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 78
# COL 0
# close price: 4024.0
# high price: 4026.8
# low price: 3982.0
# open price: 4014.8
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 79
# COL 0
# close price: 3983.1
# high price: 4063.2
# low price: 3911.0
# open price: 4019.3
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 80
# COL 0
# close price: 3987.1
# high price: 4019.2
# low price: 3969.6
# open price: 3981.4
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 81
# COL 0
# close price: 4005.0
# high price: 4018.8
# low price: 3979.0
# open price: 3987.1
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 82
# COL 0
# close price: 3987.2
# high price: 4019.9
# low price: 3962.5
# open price: 4005.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 83
# COL 0
# close price: 3922.2
# high price: 3999.0
# low price: 3884.9
# open price: 3987.2
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 84
# COL 0
# close price: 3937.9
# high price: 3948.0
# low price: 3893.1
# open price: 3922.2
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 85
# COL 0
# close price: 4023.8
# high price: 4033.3
# low price: 3923.4
# open price: 3937.9
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 86
# COL 0
# close price: 4027.8
# high price: 6950.0
# low price: 4000.0
# open price: 4018.1
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 87
# COL 0
# close price: 4098.9
# high price: 4123.4
# low price: 4022.7
# open price: 4027.8
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 88
# COL 0
# close price: 4108.1
# high price: 4141.0
# low price: 4060.2
# open price: 4098.2
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 89
# COL 0
# close price: 4103.7
# high price: 4116.3
# low price: 4086.0
# open price: 4103.5
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 90
# COL 0
# close price: 4142.0
# high price: 4148.5
# low price: 4074.3
# open price: 4102.9
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 91
# COL 0
# close price: 4848.8
# high price: 4881.8
# low price: 4131.8
# open price: 4135.9
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 92
# COL 0
# close price: 4923.7
# high price: 5300.0
# low price: 4795.2
# open price: 4848.8
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 93
# COL 0
# close price: 4894.8
# high price: 5040.3
# low price: 4800.0
# open price: 4923.7
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 94
# COL 0
# close price: 5000.4
# high price: 5032.2
# low price: 4875.5
# open price: 4899.5
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 95
# COL 0
# close price: 5050.7
# high price: 5199.0
# low price: 4935.3
# open price: 5000.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 96
# COL 0
# close price: 5164.9
# high price: 5225.4
# low price: 5031.0
# open price: 5044.3
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 97
# COL 0
# close price: 5236.0
# high price: 5300.0
# low price: 5039.9
# open price: 5166.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 98
# COL 0
# close price: 5143.5
# high price: 5241.0
# low price: 5080.9
# open price: 5241.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 99
# COL 0
# close price: 5305.7
# high price: 5400.0
# low price: 5130.9
# open price: 5143.5
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 100
# COL 0
# close price: 5016.0
# high price: 5332.4
# low price: 4926.4
# open price: 5307.6
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 101
# COL 0
# close price: 5050.6
# high price: 5075.0
# low price: 4873.8
# open price: 5018.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 102
# COL 0
# close price: 5041.7
# high price: 5091.6
# low price: 5005.5
# open price: 5051.6
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 103
# COL 0
# close price: 5133.7
# high price: 5148.9
# low price: 5002.5
# open price: 5045.8
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 104
# COL 0
# close price: 5030.7
# high price: 5167.2
# low price: 4950.1
# open price: 5134.6
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 105
# COL 0
# close price: 5174.0
# high price: 5192.3
# low price: 5004.7
# open price: 5027.4
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 106
# COL 0
# close price: 5199.8
# high price: 5227.5
# low price: 5153.9
# open price: 5173.8
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 107
# COL 0
# close price: 5260.1
# high price: 5285.0
# low price: 5194.4
# open price: 5200.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 108
# COL 0
# close price: 5260.6
# high price: 5324.2
# low price: 5183.0
# open price: 5256.8
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 109
# COL 0
# close price: 5292.4
# high price: 5330.5
# low price: 5235.5
# open price: 5258.7
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 110
# COL 0
# close price: 5258.5
# high price: 5310.4
# low price: 5172.4
# open price: 5293.5
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 111
# COL 0
# close price: 5355.2
# high price: 5395.5
# low price: 5207.6
# open price: 5257.8
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 112
# COL 0
# close price: 5494.3
# high price: 5599.9
# low price: 5338.5
# open price: 5354.9
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 113
# COL 0
# close price: 5415.3
# high price: 5578.9
# low price: 5346.0
# open price: 5494.4
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 114
# COL 0
# close price: 5221.9
# high price: 5485.2
# low price: 5137.5
# open price: 5415.3
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 115
# COL 0
# close price: 5311.8
# high price: 5515.5
# low price: 5169.0
# open price: 5221.9
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 116
# COL 0
# close price: 5296.0
# high price: 5339.4
# low price: 5262.1
# open price: 5312.1
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 117
# COL 0
# close price: 5312.4
# high price: 5700.0
# low price: 5271.9
# open price: 5295.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 118
# COL 0
# close price: 5238.5
# high price: 5334.5
# low price: 5189.6
# open price: 5310.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 119
# COL 0
# close price: 5319.6
# high price: 5340.6
# low price: 5194.3
# open price: 5239.1
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 120
# COL 0
# close price: 5386.2
# high price: 5398.5
# low price: 5318.2
# open price: 5323.4
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 121
# COL 0
# close price: 5495.3
# high price: 5537.9
# low price: 5372.1
# open price: 5382.5
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 122
# COL 0
# close price: 5769.4
# high price: 5842.6
# low price: 5483.5
# open price: 5496.1
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 123
# COL 0
# close price: 5832.6
# high price: 5901.9
# low price: 5598.8
# open price: 5769.5
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 124
# COL 0
# close price: 5773.6
# high price: 5833.3
# low price: 5703.2
# open price: 5832.3
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 125
# COL 0
# close price: 5746.4
# high price: 5801.1
# low price: 5619.6
# open price: 5771.8
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 126
# COL 0
# close price: 5844.3
# high price: 6027.7
# low price: 5748.3
# open price: 5749.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 127
# COL 0
# close price: 5980.1
# high price: 6015.7
# low price: 5800.0
# open price: 5846.9
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 128
# COL 0
# close price: 6208.4
# high price: 6244.9
# low price: 5981.5
# open price: 5984.8
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 129
# COL 0
# close price: 6377.8
# high price: 6453.1
# low price: 6144.3
# open price: 6208.4
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 130
# COL 0
# close price: 7190.8
# high price: 7385.0
# low price: 6377.7
# open price: 6377.8
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 131
# COL 0
# close price: 6976.1
# high price: 7513.9
# low price: 6785.0
# open price: 7187.9
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 132
# COL 0
# close price: 7804.9
# high price: 8102.1
# low price: 6878.0
# open price: 6974.1
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 133
# COL 0
# close price: 8001.4
# high price: 8344.2
# low price: 7679.0
# open price: 7812.6
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 134
# COL 0
# close price: 8180.9
# high price: 8250.0
# low price: 7830.0
# open price: 8000.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 135
# COL 0
# close price: 7859.0
# high price: 8319.9
# low price: 7717.2
# open price: 8180.9
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 136
# COL 0
# close price: 7354.1
# high price: 7923.3
# low price: 6927.7
# open price: 7860.1
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 137
# COL 0
# close price: 7258.4
# high price: 7460.2
# low price: 7192.3
# open price: 7354.1
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 138
# COL 0
# close price: 8157.2
# high price: 8270.5
# low price: 7247.8
# open price: 7254.6
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 139
# COL 0
# close price: 7936.2
# high price: 8156.2
# low price: 7562.3
# open price: 8154.3
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 140
# COL 0
# close price: 7904.2
# high price: 8043.0
# low price: 7780.0
# open price: 7935.6
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 141
# COL 0
# close price: 7622.8
# high price: 8009.5
# low price: 7512.0
# open price: 7904.2
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 142
# COL 0
# close price: 7853.4
# high price: 7939.1
# low price: 7470.5
# open price: 7625.8
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 143
# COL 0
# close price: 7962.6
# high price: 8111.1
# low price: 7773.4
# open price: 7852.8
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 144
# COL 0
# close price: 8025.1
# high price: 8085.3
# low price: 7910.5
# open price: 7962.6
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 145
# COL 0
# close price: 8615.7
# high price: 8727.9
# low price: 7857.2
# open price: 8024.9
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 146
# COL 0
# close price: 8758.0
# high price: 8900.1
# low price: 8594.9
# open price: 8616.9
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 147
# COL 0
# close price: 8718.0
# high price: 8793.0
# low price: 8544.2
# open price: 8753.5
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 148
# COL 0
# close price: 8644.9
# high price: 8750.0
# low price: 8415.4
# open price: 8718.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 149
# COL 0
# close price: 8262.2
# high price: 9068.9
# low price: 8032.8
# open price: 8643.5
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 150
# COL 0
# close price: 8555.6
# high price: 8578.0
# low price: 8111.5
# open price: 8262.4
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 151
# COL 0
# close price: 8545.5
# high price: 8624.0
# low price: 8445.7
# open price: 8555.6
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 152
# COL 0
# close price: 8721.9
# high price: 8807.3
# low price: 8527.5
# open price: 8545.4
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 153
# COL 0
# close price: 8134.2
# high price: 8730.4
# low price: 8097.8
# open price: 8724.7
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 154
# COL 0
# close price: 7683.2
# high price: 8134.2
# low price: 7500.0
# open price: 8134.1
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 155
# COL 0
# close price: 7782.1
# high price: 7899.2
# low price: 7577.4
# open price: 7685.1
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 156
# COL 0
# close price: 7782.8
# high price: 7855.0
# low price: 7456.5
# open price: 7781.5
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 157
# COL 0
# close price: 7974.8
# high price: 8094.3
# low price: 7747.7
# open price: 7785.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 158
# COL 0
# close price: 7893.6
# high price: 8041.1
# low price: 7767.2
# open price: 7981.5
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 159
# COL 0
# close price: 7631.1
# high price: 7934.8
# low price: 7501.0
# open price: 7898.1
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 160
# COL 0
# close price: 7985.8
# high price: 8013.5
# low price: 7513.4
# open price: 7631.2
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 161
# COL 0
# close price: 7881.5
# high price: 8010.4
# low price: 7700.3
# open price: 7986.4
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 162
# COL 0
# close price: 8127.6
# high price: 8199.0
# low price: 7795.4
# open price: 7885.4
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 163
# COL 0
# close price: 8218.9
# high price: 8308.9
# low price: 8017.8
# open price: 8132.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 164
# COL 0
# close price: 8648.2
# high price: 8678.3
# low price: 8153.6
# open price: 8218.9
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 165
# COL 0
# close price: 8811.4
# high price: 8850.0
# low price: 8578.6
# open price: 8648.2
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 166
# COL 0
# close price: 8956.9
# high price: 9328.3
# low price: 8768.0
# open price: 8810.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 167
# COL 0
# close price: 9310.2
# high price: 9439.0
# low price: 8954.1
# open price: 8954.2
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 168
# COL 0
# close price: 9082.3
# high price: 9338.3
# low price: 8963.9
# open price: 9311.4
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 169
# COL 0
# close price: 9256.2
# high price: 9293.4
# low price: 9043.2
# open price: 9082.4
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 170
# COL 0
# close price: 9513.2
# high price: 9586.6
# low price: 9182.2
# open price: 9249.7
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 171
# COL 0
# close price: 10153.1
# high price: 10171.3
# low price: 9513.2
# open price: 9513.2
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 172
# COL 0
# close price: 10739.7
# high price: 11148.4
# low price: 9975.0
# open price: 10159.3
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 173
# COL 0
# close price: 10890.6
# high price: 11374.5
# low price: 10551.6
# open price: 10739.8
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 174
# COL 0
# close price: 11048.0
# high price: 11132.1
# low price: 10628.1
# open price: 10890.8
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 175
# COL 0
# close price: 11815.4
# high price: 11842.2
# low price: 11033.8
# open price: 11041.6
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 176
# COL 0
# close price: 13067.3
# high price: 13947.7
# low price: 11743.1
# open price: 11820.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 177
# COL 0
# close price: 11329.8
# high price: 13427.6
# low price: 10542.7
# open price: 13067.4
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 178
# COL 0
# close price: 12409.5
# high price: 12474.2
# low price: 10996.0
# open price: 11317.4
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 179
# COL 0
# close price: 11892.9
# high price: 12436.6
# low price: 11479.6
# open price: 12412.7
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 180
# COL 0
# close price: 10831.1
# high price: 12182.5
# low price: 10770.4
# open price: 11891.8
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 181
# COL 0
# close price: 10630.3
# high price: 11251.3
# low price: 10042.2
# open price: 10831.1
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 182
# COL 0
# close price: 10836.7
# high price: 10928.6
# low price: 9750.0
# open price: 10619.5
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 183
# COL 0
# close price: 11933.3
# high price: 11974.0
# low price: 10828.9
# open price: 10828.9
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 184
# COL 0
# close price: 11158.9
# high price: 11994.0
# low price: 11083.1
# open price: 11924.3
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 185
# COL 0
# close price: 10973.1
# high price: 11397.9
# low price: 10808.2
# open price: 11161.3
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 186
# COL 0
# close price: 11253.6
# high price: 11650.8
# low price: 10965.1
# open price: 10971.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 187
# COL 0
# close price: 11414.5
# high price: 11526.5
# low price: 11107.6
# open price: 11253.5
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 188
# COL 0
# close price: 12249.0
# high price: 12338.0
# low price: 11296.4
# open price: 11413.7
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 189
# COL 0
# close price: 12533.8
# high price: 12788.0
# low price: 12097.6
# open price: 12242.8
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 190
# COL 0
# close price: 12101.0
# high price: 13139.0
# low price: 11572.2
# open price: 12537.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 191
# COL 0
# close price: 11335.6
# high price: 12101.2
# low price: 11011.0
# open price: 12097.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 192
# COL 0
# close price: 11760.0
# high price: 11880.4
# low price: 11101.3
# open price: 11338.7
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 193
# COL 0
# close price: 11356.6
# high price: 11795.0
# low price: 10850.0
# open price: 11757.4
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 194
# COL 0
# close price: 10185.8
# high price: 11444.0
# low price: 10101.9
# open price: 11350.5
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 195
# COL 0
# close price: 10854.0
# high price: 11071.4
# low price: 9857.8
# open price: 10185.8
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 196
# COL 0
# close price: 9430.6
# high price: 11028.0
# low price: 9352.2
# open price: 10836.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 197
# COL 0
# close price: 9669.1
# high price: 9950.0
# low price: 9072.5
# open price: 9435.7
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 198
# COL 0
# close price: 10621.8
# high price: 10771.0
# low price: 9283.3
# open price: 9666.6
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 199
# COL 0
# close price: 10502.9
# high price: 10752.1
# low price: 10131.2
# open price: 10629.3
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 200
# COL 0
# close price: 10732.1
# high price: 11053.3
# low price: 10371.3
# open price: 10503.2
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 201
# COL 0
# close price: 10579.3
# high price: 10808.0
# low price: 10310.0
# open price: 10734.9
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 202
# COL 0
# close price: 10338.8
# high price: 10670.5
# low price: 10097.9
# open price: 10579.6
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 203
# COL 0
# close price: 9871.9
# high price: 10344.3
# low price: 9833.9
# open price: 10343.1
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 204
# COL 0
# close price: 9759.1
# high price: 9926.0
# low price: 9540.6
# open price: 9871.8
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 205
# COL 0
# close price: 9879.9
# high price: 10180.0
# low price: 9726.6
# open price: 9759.5
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 206
# COL 0
# close price: 9832.0
# high price: 9880.7
# low price: 9637.5
# open price: 9877.2
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 207
# COL 0
# close price: 9485.5
# high price: 10179.4
# low price: 9337.0
# open price: 9832.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 208
# COL 0
# close price: 9535.7
# high price: 9587.1
# low price: 9170.0
# open price: 9475.9
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 209
# COL 0
# close price: 9503.4
# high price: 9726.0
# low price: 9394.1
# open price: 9540.4
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 210
# COL 0
# close price: 9579.0
# high price: 9705.5
# low price: 9404.0
# open price: 9508.1
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 211
# COL 0
# close price: 10076.6
# high price: 10102.0
# low price: 9556.9
# open price: 9579.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 212
# COL 0
# close price: 10353.3
# high price: 10450.0
# low price: 9875.0
# open price: 10072.8
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 213
# COL 0
# close price: 10521.1
# high price: 10675.6
# low price: 10290.3
# open price: 10353.4
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 214
# COL 0
# close price: 10815.7
# high price: 10899.1
# low price: 10502.2
# open price: 10518.2
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 215
# COL 0
# close price: 10933.1
# high price: 11028.7
# low price: 10542.8
# open price: 10812.3
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 216
# COL 0
# close price: 11821.7
# high price: 11931.1
# low price: 10930.6
# open price: 10930.6
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 217
# COL 0
# close price: 11480.6
# high price: 12309.3
# low price: 11207.2
# open price: 11826.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 218
# COL 0
# close price: 11965.7
# high price: 12158.0
# low price: 11388.6
# open price: 11480.6
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 219
# COL 0
# close price: 11997.6
# high price: 12059.6
# low price: 11530.5
# open price: 11965.7
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 220
# COL 0
# close price: 11877.8
# high price: 12041.8
# low price: 11685.0
# open price: 11997.6
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 221
# COL 0
# close price: 11314.0
# high price: 11972.0
# low price: 11268.3
# open price: 11878.3
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 222
# COL 0
# close price: 11539.0
# high price: 11591.5
# low price: 11121.6
# open price: 11314.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 223
# COL 0
# close price: 11396.5
# high price: 11560.2
# low price: 11246.9
# open price: 11541.6
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 224
# COL 0
# close price: 10894.4
# high price: 11442.4
# low price: 10790.5
# open price: 11397.3
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 225
# COL 0
# close price: 10049.7
# high price: 10893.8
# low price: 9943.9
# open price: 10889.4
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 226
# COL 0
# close price: 10293.7
# high price: 10458.4
# low price: 9522.5
# open price: 10049.1
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 227
# COL 0
# close price: 10328.3
# high price: 10520.1
# low price: 9774.2
# open price: 10293.1
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 228
# COL 0
# close price: 10215.6
# high price: 10460.6
# low price: 10000.0
# open price: 10328.3
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 229
# COL 0
# close price: 10308.0
# high price: 10499.0
# low price: 10074.1
# open price: 10215.6
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 230
# COL 0
# close price: 10912.2
# high price: 10948.2
# low price: 10255.6
# open price: 10298.6
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 231
# COL 0
# close price: 10755.6
# high price: 10950.6
# low price: 10568.3
# open price: 10913.5
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 232
# COL 0
# close price: 10140.8
# high price: 10800.7
# low price: 9876.0
# open price: 10755.6
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 233
# COL 0
# close price: 10103.1
# high price: 10234.0
# low price: 9756.5
# open price: 10140.8
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 234
# COL 0
# close price: 10363.8
# high price: 10443.6
# low price: 10027.0
# open price: 10103.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 235
# COL 0
# close price: 10133.7
# high price: 10399.9
# low price: 9890.0
# open price: 10366.4
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 236
# COL 0
# close price: 10136.2
# high price: 10329.9
# low price: 9915.5
# open price: 10134.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 237
# COL 0
# close price: 10368.8
# high price: 10600.0
# low price: 10132.3
# open price: 10136.2
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 238
# COL 0
# close price: 10184.2
# high price: 10387.6
# low price: 10051.0
# open price: 10369.8
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 239
# COL 0
# close price: 9724.5
# high price: 10288.1
# low price: 9602.2
# open price: 10184.2
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 240
# COL 0
# close price: 9493.5
# high price: 9725.1
# low price: 9326.0
# open price: 9722.3
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 241
# COL 0
# close price: 9578.6
# high price: 9689.6
# low price: 9357.4
# open price: 9493.6
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 242
# COL 0
# close price: 9584.4
# high price: 9681.6
# low price: 9430.0
# open price: 9579.8
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 243
# COL 0
# close price: 9728.7
# high price: 9809.0
# low price: 9521.7
# open price: 9585.2
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 244
# COL 0
# close price: 10339.3
# high price: 10434.8
# low price: 9720.5
# open price: 9728.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 245
# COL 0
# close price: 10606.9
# high price: 10762.0
# low price: 10270.5
# open price: 10338.1
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 246
# COL 0
# close price: 10560.7
# high price: 10792.3
# low price: 10372.0
# open price: 10605.7
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 247
# COL 0
# close price: 10564.6
# high price: 10692.6
# low price: 10450.0
# open price: 10563.2
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 248
# COL 0
# close price: 10295.9
# high price: 10900.0
# low price: 10181.3
# open price: 10564.5
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 249
# COL 0
# close price: 10455.3
# high price: 10550.0
# low price: 10294.2
# open price: 10295.9
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 250
# COL 0
# close price: 10384.3
# high price: 10582.0
# low price: 10227.1
# open price: 10455.4
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 251
# COL 0
# close price: 10305.4
# high price: 10480.7
# low price: 10069.5
# open price: 10384.3
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 252
# COL 0
# close price: 10103.1
# high price: 10379.5
# low price: 9960.0
# open price: 10304.8
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 253
# COL 0
# close price: 10157.3
# high price: 10273.1
# low price: 9930.4
# open price: 10102.3
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 254
# COL 0
# close price: 10412.5
# high price: 10430.0
# low price: 10038.9
# open price: 10157.3
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 255
# COL 0
# close price: 10339.3
# high price: 10430.0
# low price: 10152.5
# open price: 10412.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 256
# COL 0
# close price: 10334.0
# high price: 10416.7
# low price: 10225.7
# open price: 10339.3
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 257
# COL 0
# close price: 10302.1
# high price: 10359.0
# low price: 10245.1
# open price: 10334.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 258
# COL 0
# close price: 10250.7
# high price: 10350.0
# low price: 10082.5
# open price: 10301.8
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 259
# COL 0
# close price: 10187.4
# high price: 10270.4
# low price: 10144.4
# open price: 10250.9
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 260
# COL 0
# close price: 10155.5
# high price: 10255.0
# low price: 10100.0
# open price: 10186.1
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 261
# COL 0
# close price: 10246.5
# high price: 10317.5
# low price: 9685.0
# open price: 10155.9
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 262
# COL 0
# close price: 10169.9
# high price: 10278.1
# low price: 10075.0
# open price: 10244.4
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 263
# COL 0
# close price: 9984.9
# high price: 10177.6
# low price: 9910.0
# open price: 10170.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 264
# COL 0
# close price: 10026.6
# high price: 10086.5
# low price: 9861.1
# open price: 9984.8
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 265
# COL 0
# close price: 9704.1
# high price: 10045.1
# low price: 9631.7
# open price: 10026.5
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 266
# COL 0
# close price: 8503.8
# high price: 9790.8
# low price: 7844.1
# open price: 9704.1
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 267
# COL 0
# close price: 8435.3
# high price: 8725.8
# low price: 8220.1
# open price: 8501.5
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 268
# COL 0
# close price: 8062.3
# high price: 8460.7
# low price: 7752.0
# open price: 8435.1
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 269
# COL 0
# close price: 8178.5
# high price: 8260.9
# low price: 7860.7
# open price: 8062.3
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 270
# COL 0
# close price: 8199.7
# high price: 8307.2
# low price: 8008.9
# open price: 8178.2
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 271
# COL 0
# close price: 8041.8
# high price: 8229.1
# low price: 7898.5
# open price: 8198.8
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 272
# COL 0
# close price: 8287.5
# high price: 8332.1
# low price: 7722.3
# open price: 8042.6
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 273
# COL 0
# close price: 8288.3
# high price: 8496.1
# low price: 8178.1
# open price: 8289.1
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 274
# COL 0
# close price: 8353.7
# high price: 8367.0
# low price: 8149.1
# open price: 8287.5
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 275
# COL 0
# close price: 8221.0
# high price: 8388.3
# low price: 8064.0
# open price: 8353.9
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 276
# COL 0
# close price: 8132.6
# high price: 8228.1
# low price: 8015.0
# open price: 8223.6
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 277
# COL 0
# close price: 8126.6
# high price: 8175.9
# low price: 8011.1
# open price: 8132.9
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 278
# COL 0
# close price: 7850.8
# high price: 8151.0
# low price: 7800.0
# open price: 8127.2
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 279
# COL 0
# close price: 8185.1
# high price: 8293.0
# low price: 7768.2
# open price: 7854.9
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 280
# COL 0
# close price: 8167.6
# high price: 8324.0
# low price: 8100.7
# open price: 8187.2
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 281
# COL 0
# close price: 8561.6
# high price: 8695.9
# low price: 8113.9
# open price: 8167.8
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 282
# COL 0
# close price: 8555.9
# high price: 8642.3
# low price: 8424.1
# open price: 8561.6
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 283
# COL 0
# close price: 8256.4
# high price: 8777.0
# low price: 8229.2
# open price: 8555.9
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 284
# COL 0
# close price: 8299.8
# high price: 8394.3
# low price: 8248.7
# open price: 8255.8
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 285
# COL 0
# close price: 8273.9
# high price: 8448.6
# low price: 8163.6
# open price: 8299.9
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 286
# COL 0
# close price: 8345.9
# high price: 8379.9
# low price: 8208.0
# open price: 8273.9
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 287
# COL 0
# close price: 8160.7
# high price: 8399.1
# low price: 8110.3
# open price: 8345.8
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 288
# COL 0
# close price: 7995.5
# high price: 8179.1
# low price: 7918.1
# open price: 8159.3
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 289
# COL 0
# close price: 8069.9
# high price: 8118.4
# low price: 7930.5
# open price: 7992.6
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 290
# COL 0
# close price: 7946.8
# high price: 8113.6
# low price: 7812.6
# open price: 8069.9
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 291
# COL 0
# close price: 7951.7
# high price: 8081.1
# low price: 7869.7
# open price: 7946.8
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 292
# COL 0
# close price: 8217.1
# high price: 8289.4
# low price: 7870.2
# open price: 7951.7
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 293
# COL 0
# close price: 8195.0
# high price: 8323.0
# low price: 8146.8
# open price: 8217.1
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 294
# COL 0
# close price: 8023.0
# high price: 8292.9
# low price: 7990.6
# open price: 8195.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 295
# COL 0
# close price: 7465.9
# high price: 8045.0
# low price: 7310.0
# open price: 8020.1
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 296
# COL 0
# close price: 7412.9
# high price: 7497.0
# low price: 7340.0
# open price: 7465.9
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 297
# COL 0
# close price: 8654.6
# high price: 8769.0
# low price: 7382.1
# open price: 7412.9
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 298
# COL 0
# close price: 9233.5
# high price: 10348.6
# low price: 8637.5
# open price: 8654.7
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 299
# COL 0
# close price: 9525.7
# high price: 9785.0
# low price: 9043.7
# open price: 9233.4
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 300
# COL 0
# close price: 9203.3
# high price: 9898.0
# low price: 9200.0
# open price: 9527.1
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 301
# COL 0
# close price: 9404.4
# high price: 9531.4
# low price: 9101.0
# open price: 9207.6
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 302
# COL 0
# close price: 9154.3
# high price: 9406.2
# low price: 9001.9
# open price: 9404.4
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 303
# COL 0
# close price: 9141.6
# high price: 9384.2
# low price: 8946.6
# open price: 9154.1
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 304
# COL 0
# close price: 9226.1
# high price: 9272.5
# low price: 9038.1
# open price: 9142.7
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 305
# COL 0
# close price: 9287.4
# high price: 9368.3
# low price: 9190.0
# open price: 9226.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 306
# COL 0
# close price: 9194.1
# high price: 9357.5
# low price: 9075.9
# open price: 9287.5
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 307
# COL 0
# close price: 9394.9
# high price: 9502.9
# low price: 9118.6
# open price: 9194.6
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 308
# COL 0
# close price: 9308.9
# high price: 9453.0
# low price: 9180.9
# open price: 9394.8
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 309
# COL 0
# close price: 9335.6
# high price: 9430.3
# low price: 9253.6
# open price: 9308.7
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 310
# COL 0
# close price: 9214.2
# high price: 9370.0
# low price: 9060.0
# open price: 9335.7
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 311
# COL 0
# close price: 8774.2
# high price: 9258.2
# low price: 8650.0
# open price: 9214.3
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 312
# COL 0
# close price: 8808.4
# high price: 8875.0
# low price: 8726.0
# open price: 8774.2
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 313
# COL 0
# close price: 9033.9
# high price: 9128.7
# low price: 8750.0
# open price: 8808.9
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 314
# COL 0
# close price: 8734.7
# high price: 9065.6
# low price: 8628.9
# open price: 9033.8
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 315
# COL 0
# close price: 8812.7
# high price: 8872.7
# low price: 8550.0
# open price: 8733.9
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 316
# COL 0
# close price: 8776.6
# high price: 8834.8
# low price: 8711.2
# open price: 8812.7
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 317
# COL 0
# close price: 8645.9
# high price: 8799.4
# low price: 8596.4
# open price: 8776.7
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 318
# COL 0
# close price: 8470.9
# high price: 8780.0
# low price: 8404.6
# open price: 8646.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 319
# COL 0
# close price: 8490.7
# high price: 8529.9
# low price: 8432.4
# open price: 8470.9
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 320
# COL 0
# close price: 8500.7
# high price: 8618.7
# low price: 8373.6
# open price: 8491.1
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 321
# COL 0
# close price: 8188.4
# high price: 8500.8
# low price: 8070.0
# open price: 8500.7
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 322
# COL 0
# close price: 8131.6
# high price: 8212.6
# low price: 8010.0
# open price: 8188.4
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 323
# COL 0
# close price: 8095.4
# high price: 8230.2
# low price: 8042.1
# open price: 8131.9
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 324
# COL 0
# close price: 7626.3
# high price: 8132.3
# low price: 7500.0
# open price: 8095.5
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 325
# COL 0
# close price: 7265.5
# high price: 7758.5
# low price: 6801.0
# open price: 7626.3
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 326
# COL 0
# close price: 7310.8
# high price: 7341.3
# low price: 7078.9
# open price: 7265.2
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 327
# COL 0
# close price: 6898.9
# high price: 7329.7
# low price: 6856.6
# open price: 7310.6
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 328
# COL 0
# close price: 7109.5
# high price: 7548.0
# low price: 6516.5
# open price: 6900.4
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 329
# COL 0
# close price: 7155.6
# high price: 7334.6
# low price: 7022.6
# open price: 7109.6
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 330
# COL 0
# close price: 7508.0
# high price: 7652.0
# low price: 6850.2
# open price: 7155.5
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 331
# COL 0
# close price: 7419.7
# high price: 7634.5
# low price: 7366.0
# open price: 7509.3
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 332
# COL 0
# close price: 7739.3
# high price: 7844.1
# low price: 7397.7
# open price: 7419.0
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 333
# COL 0
# close price: 7544.8
# high price: 7796.4
# low price: 7452.8
# open price: 7739.5
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 334
# COL 0
# close price: 7391.2
# high price: 7544.9
# low price: 7233.9
# open price: 7544.9
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 335
# COL 0
# close price: 7294.7
# high price: 7418.9
# low price: 7160.3
# open price: 7391.1
# position size : 0.0
# cash: 100000.0
# entries: 0
#
# INDEX 336
# COL 0
# ...
# low price: 2634.33
# open price: 2675.31
# position size : 0.0
# cash: 113430.0591204107
# entries: 25
#
# INDEX 2099
# COL 1
# close price: 2602.38
# high price: 2663.0
# low price: 2574.96
# open price: 2657.61
# position size : 0.0
# cash: 113430.0591204107
# entries: 25
#
# INDEX 2100
# COL 1
# close price: 2448.4
# high price: 2659.0
# low price: 2413.89
# open price: 2602.39
# position size : 0.0
# cash: 113430.0591204107
# entries: 25
#
# INDEX 2101
# COL 1
# close price: 2364.29
# high price: 2499.03
# low price: 2352.43
# open price: 2448.35
# position size : 0.0
# cash: 113430.0591204107
# entries: 25
#
# INDEX 2102
# COL 1
# close price: 2349.69
# high price: 2403.37
# low price: 2309.16
# open price: 2364.28
# position size : 0.0
# cash: 113430.0591204107
# entries: 25
#
# INDEX 2103
# COL 1
# close price: 2414.43
# high price: 2441.64
# low price: 2339.56
# open price: 2349.7
# position size : 0.0
# cash: 113430.0591204107
# entries: 25
#
# INDEX 2104
# COL 1
# close price: 2414.95
# high price: 2428.52
# low price: 2390.03
# open price: 2414.43
# position size : 0.0
# cash: 113430.0591204107
# entries: 25
#
# INDEX 2105
# COL 1
# close price: 2440.16
# high price: 2457.63
# low price: 2407.03
# open price: 2414.95
# position size : 0.0
# cash: 113430.0591204107
# entries: 25
#
# INDEX 2106
# COL 1
# close price: 2422.95
# high price: 2521.25
# low price: 2403.47
# open price: 2440.15
# position size : 0.0
# cash: 113430.0591204107
# entries: 25
#
# INDEX 2107
# COL 1
# close price: 2440.87
# high price: 2466.94
# low price: 2400.98
# open price: 2422.95
# position size : 0.0
# cash: 113430.0591204107
# entries: 25
#
# INDEX 2108
# COL 1
# close price: 2370.37
# high price: 2473.92
# low price: 2351.35
# open price: 2440.88
# position size : 0.0
# cash: 113430.0591204107
# entries: 25
#
# INDEX 2109
# COL 1
# close price: 2386.25
# high price: 2421.39
# low price: 2331.2
# open price: 2370.39
# position size : 0.0
# cash: 113430.0591204107
# entries: 25
#
# INDEX 2110
# COL 1
# close price: 2439.45
# high price: 2471.6
# low price: 2382.35
# open price: 2386.25
# position size : 0.0
# cash: 113430.0591204107
# entries: 25
#
# INDEX 2111
# COL 1
# close price: 2476.37
# high price: 2490.27
# low price: 2434.51
# open price: 2439.46
# position size : 0.0
# cash: 113430.0591204107
# entries: 25
#
# INDEX 2112
# COL 1
# close price: 2468.91
# high price: 2484.6
# low price: 2436.4
# open price: 2476.37
# position size : 0.0
# cash: 113430.0591204107
# entries: 25
#
# INDEX 2113
# COL 1
# close price: 2630.05
# high price: 2654.15
# low price: 2443.61
# open price: 2468.91
# position size : 0.0
# cash: 113430.0591204107
# entries: 25
#
# INDEX 2114
# COL 1
# close price: 2607.8
# high price: 2688.69
# low price: 2537.52
# open price: 2630.01
# position size : 0.0
# cash: 113430.0591204107
# entries: 25
#
# INDEX 2115
# COL 1
# close price: 2611.34
# high price: 2648.0
# low price: 2589.19
# open price: 2607.76
# position size : 0.0
# cash: 113430.0591204107
# entries: 25
#
# INDEX 2116
# COL 1
# close price: 2605.68
# high price: 2648.2
# low price: 2575.8
# open price: 2611.35
# position size : 0.0
# cash: 113430.0591204107
# entries: 25
#
# INDEX 2117
# COL 1
# close price: 2641.85
# high price: 2675.65
# low price: 2596.74
# open price: 2605.77
# position size : 0.0
# cash: 113430.0591204107
# entries: 25
#
# INDEX 2118
# COL 1
# close price: 2648.14
# high price: 2663.31
# low price: 2630.7
# open price: 2641.85
# position size : 0.0
# cash: 113430.0591204107
# entries: 25
#
# INDEX 2119
# COL 1
# close price: 2747.19
# high price: 2759.11
# low price: 2635.69
# open price: 2648.16
# position size : 0.0
# cash: 113430.0591204107
# entries: 25
#
# INDEX 2120
# COL 1
# close price: 2666.75
# high price: 2768.88
# low price: 2655.01
# open price: 2747.16
# position size : 0.0
# cash: 113430.0591204107
# entries: 25
#
# INDEX 2121
# COL 1
# close price: 2622.59
# high price: 2671.61
# low price: 2606.39
# open price: 2666.76
# position size : 0.0
# cash: 113430.0591204107
# entries: 25
#
# INDEX 2122
# COL 1
# close price: 2524.79
# high price: 2628.2
# low price: 2448.44
# open price: 2622.6
# position size : 0.0
# cash: 113430.0591204107
# entries: 25
#
# INDEX 2123
# COL 1
# close price: 2536.22
# high price: 2562.18
# low price: 2507.06
# open price: 2524.79
# position size : 0.0
# cash: 113430.0591204107
# entries: 25
#
# INDEX 2124
# COL 1
# close price: 2440.52
# high price: 2566.33
# low price: 2382.48
# open price: 2536.22
# position size : 0.0
# cash: 113430.0591204107
# entries: 25
#
# INDEX 2125
# COL 1
# close price: 2482.65
# high price: 2508.13
# low price: 2430.4
# open price: 2440.53
# position size : 0.0
# cash: 113430.0591204107
# entries: 25
#
# INDEX 2126
# COL 1
# close price: 2507.99
# high price: 2527.98
# low price: 2464.2
# open price: 2482.65
# position size : 0.0
# cash: 113430.0591204107
# entries: 25
#
# INDEX 2127
# COL 1
# close price: 2567.32
# high price: 2589.69
# low price: 2471.85
# open price: 2508.0
# position size : 0.0
# cash: 113430.0591204107
# entries: 25
#
# INDEX 2128
# COL 1
# close price: 2638.81
# high price: 2681.97
# low price: 2561.45
# open price: 2567.32
# position size : 0.0
# cash: 113430.0591204107
# entries: 25
#
# INDEX 2129
# COL 1
# close price: 2658.72
# high price: 2722.23
# low price: 2600.47
# open price: 2638.81
# position size : 0.0
# cash: 113430.0591204107
# entries: 25
#
# INDEX 2130
# COL 1
# close price: 2518.51
# high price: 2668.85
# low price: 2503.33
# open price: 2658.82
# position size : 0.0
# cash: 113430.0591204107
# entries: 25
#
# INDEX 2131
# COL 1
# close price: 2511.93
# high price: 2586.69
# low price: 2467.82
# open price: 2518.51
# position size : 0.0
# cash: 113430.0591204107
# entries: 25
#
# INDEX 2132
# COL 1
# close price: 2494.11
# high price: 2523.21
# low price: 2470.14
# open price: 2511.86
# position size : 0.0
# cash: 113430.0591204107
# entries: 25
#
# INDEX 2133
# COL 1
# close price: 2457.54
# high price: 2496.34
# low price: 2410.73
# open price: 2494.17
# position size : 0.0
# cash: 113430.0591204107
# entries: 25
#
# INDEX 2134
# COL 1
# close price: 2398.4
# high price: 2491.28
# low price: 2357.31
# open price: 2457.55
# position size : 0.0
# cash: 113430.0591204107
# entries: 25
#
# INDEX 2135
# COL 1
# close price: 2422.24
# high price: 2479.94
# low price: 2381.14
# open price: 2398.18
# position size : 0.0
# cash: 113430.0591204107
# entries: 25
#
# INDEX 2136
# COL 1
# close price: 2722.14
# high price: 2744.51
# low price: 2420.46
# open price: 2422.24
# position size : 0.0
# cash: 113430.0591204107
# entries: 25
#
# INDEX 2137
# COL 1
# close price: 2895.18
# high price: 2916.2
# low price: 2700.0
# open price: 2721.76
# position size : 0.0
# cash: 113430.0591204107
# entries: 25
#
# INDEX 2138
# COL 1
# close price: 2961.87
# high price: 2981.79
# low price: 2886.43
# open price: 2895.32
# position size : 0.0
# cash: 113430.0591204107
# entries: 0
#
# INDEX 2139
# COL 1
# close price: 3126.47
# high price: 3157.12
# low price: 2952.67
# open price: 2961.88
# position size : 0.0
# cash: 113430.0591204107
# entries: 0
#
# INDEX 2140
# COL 1
# close price: 3183.44
# high price: 3248.45
# low price: 3069.3
# open price: 3126.48
# position size : 0.0
# cash: 113430.0591204107
# entries: 0
#
# INDEX 2141
# COL 1
# close price: 3371.03
# high price: 3386.98
# low price: 3105.07
# open price: 3183.18
# position size : 0.0
# cash: 113430.0591204107
# entries: 0
#
# INDEX 2142
# COL 1
# close price: 3245.15
# high price: 3442.14
# low price: 3208.89
# open price: 3371.03
# position size : 0.0
# cash: 113430.0591204107
# entries: 0
#
# INDEX 2143
# COL 1
# close price: 3187.11
# high price: 3330.51
# low price: 3112.45
# open price: 3244.81
# position size : 0.0
# cash: 113430.0591204107
# entries: 0
#
# INDEX 2144
# COL 1
# close price: 3058.94
# high price: 3239.73
# low price: 3026.25
# open price: 3187.12
# position size : 0.0
# cash: 113430.0591204107
# entries: 0
#
# INDEX 2145
# COL 1
# close price: 3090.01
# high price: 3130.96
# low price: 3010.56
# open price: 3059.1
# position size : 0.0
# cash: 113430.0591204107
# entries: 0
#
# INDEX 2146
# COL 1
# close price: 3132.72
# high price: 3219.92
# low price: 3072.04
# open price: 3089.56
# position size : 0.0
# cash: 113430.0591204107
# entries: 0
#
# INDEX 2147
# COL 1
# close price: 3075.87
# high price: 3161.63
# low price: 3035.0
# open price: 3133.03
# position size : 0.0
# cash: 113430.0591204107
# entries: 0
#
# INDEX 2148
# COL 1
# close price: 3208.18
# high price: 3224.19
# low price: 3050.1
# open price: 3075.86
# position size : 0.0
# cash: 113430.0591204107
# entries: 0
#
# INDEX 2149
# COL 1
# close price: 3106.93
# high price: 3221.64
# low price: 3065.55
# open price: 3208.17
# position size : 0.0
# cash: 113430.0591204107
# entries: 0
#
# INDEX 2150
# COL 1
# close price: 3069.73
# high price: 3159.4
# low price: 3029.48
# open price: 3107.37
# position size : 0.0
# cash: 113430.0591204107
# entries: 0
#
# INDEX 2151
# COL 1
# close price: 3356.07
# high price: 3386.49
# low price: 3032.72
# open price: 3069.73
# position size : 0.0
# cash: 113430.0591204107
# entries: 0
#
# INDEX 2152
# COL 1
# close price: 3327.7
# high price: 3425.59
# low price: 3259.07
# open price: 3356.08
# position size : 0.0
# cash: 113430.0591204107
# entries: 0
#
# INDEX 2153
# COL 1
# close price: 3393.96
# high price: 3495.79
# low price: 3312.94
# open price: 3327.7
# position size : 0.0
# cash: 113430.0591204107
# entries: 0
#
# INDEX 2154
# COL 1
# close price: 3360.88
# high price: 3449.39
# low price: 3281.79
# open price: 3393.97
# position size : 0.0
# cash: 113430.0591204107
# entries: 0
#
# INDEX 2155
# COL 1
# close price: 3414.77
# high price: 3546.4
# low price: 3300.89
# open price: 3360.88
# position size : 0.0
# cash: 113430.0591204107
# entries: 0
#
# INDEX 2156
# COL 1
# close price: 3324.78
# high price: 3462.15
# low price: 3252.64
# open price: 3414.76
# position size : 0.0
# cash: 113430.0591204107
# entries: 0
#
# INDEX 2157
# COL 1
# close price: 3653.55
# high price: 3684.77
# low price: 3302.23
# open price: 3324.79
# position size : 0.0
# cash: 113430.0591204107
# entries: 0
#
# INDEX 2158
# COL 1
# close price: 3579.05
# high price: 3661.5
# low price: 3530.21
# open price: 3653.47
# position size : 0.0
# cash: 113430.0591204107
# entries: 0
#
# INDEX 2159
# COL 1
# close price: 3592.39
# high price: 3645.0
# low price: 3535.25
# open price: 3579.06
# position size : 0.0
# cash: 113430.0591204107
# entries: 0
#
# INDEX 2160
# COL 1
# close price: 3703.26
# high price: 3739.39
# low price: 3567.61
# open price: 3592.4
# position size : 0.0
# cash: 113430.0591204107
# entries: 0
#
# INDEX 2161
# COL 1
# close price: 3708.44
# high price: 3746.57
# low price: 3659.37
# open price: 3703.26
# position size : 0.0
# cash: 113430.0591204107
# entries: 0
#
# INDEX 2162
# COL 1
# close price: 3643.18
# high price: 3758.91
# low price: 3556.18
# open price: 3708.45
# position size : 0.0
# cash: 113430.0591204107
# entries: 0
#
# INDEX 2163
# COL 1
# close price: 3614.49
# high price: 3669.7
# low price: 3502.08
# open price: 3643.18
# position size : 0.0
# cash: 113430.0591204107
# entries: 0
#
# INDEX 2164
# COL 1
# close price: 3838.31
# high price: 3887.09
# low price: 3614.41
# open price: 3614.5
# position size : 0.0
# cash: 113430.0591204107
# entries: 0
#
# INDEX 2165
# COL 1
# close price: 3785.11
# high price: 3955.36
# low price: 3666.43
# open price: 3837.91
# position size : 0.0
# cash: 113430.0591204107
# entries: 0
#
# INDEX 2166
# COL 1
# close price: 3999.55
# high price: 4088.05
# low price: 3777.83
# open price: 3785.1
# position size : 0.0
# cash: 113430.0591204107
# entries: 0
#
# INDEX 2167
# COL 1
# close price: 3996.17
# high price: 4024.45
# low price: 3967.85
# open price: 3999.55
# position size : 0.0
# cash: 113430.0591204107
# entries: 0
#
# INDEX 2168
# COL 1
# close price: 4004.05
# high price: 4015.91
# low price: 3923.61
# open price: 3996.67
# position size : 0.0
# cash: 113430.0591204107
# entries: 0
#
# INDEX 2169
# COL 1
# close price: 3712.42
# high price: 4005.91
# low price: 3463.4
# open price: 4004.48
# position size : 0.0
# cash: 113430.0591204107
# entries: 0
#
# INDEX 2170
# COL 1
# close price: 3628.45
# high price: 3780.52
# low price: 3514.55
# open price: 3711.77
# position size : 0.0
# cash: 113430.0591204107
# entries: 0
#
# INDEX 2171
# COL 1
# close price: 3831.76
# high price: 3848.41
# low price: 3563.1
# open price: 3628.45
# position size : 0.0
# cash: 113430.0591204107
# entries: 0
#
# INDEX 2172
# COL 1
# close price: 3881.79
# high price: 3987.46
# low price: 3797.28
# open price: 3831.75
# position size : 0.0
# cash: 113430.0591204107
# entries: 0
#
# INDEX 2173
# COL 1
# close price: 3907.3
# high price: 3967.81
# low price: 3853.35
# open price: 3881.79
# position size : 0.0
# cash: 113430.0591204107
# entries: 75
#
# INDEX 2174
# COL 1
# close price: 3870.4
# high price: 3944.93
# low price: 3822.68
# open price: 3907.3
# position size : 0.0
# cash: 113430.0591204107
# entries: 75
#
# INDEX 2175
# COL 1
# close price: 3958.93
# high price: 3974.45
# low price: 3832.01
# open price: 3870.4
# position size : 0.0
# cash: 113430.0591204107
# entries: 75
#
# INDEX 2176
# COL 1
# close price: 3986.05
# high price: 4107.55
# low price: 3883.97
# open price: 3959.4
# position size : 0.0
# cash: 113430.0591204107
# entries: 75
#
# INDEX 2177
# COL 1
# close price: 3893.27
# high price: 4040.76
# low price: 3847.52
# open price: 3986.05
# position size : 0.0
# cash: 113430.0591204107
# entries: 75
#
# INDEX 2178
# COL 1
# close price: 3870.33
# high price: 3902.66
# low price: 3804.89
# open price: 3893.14
# position size : 0.0
# cash: 113430.0591204107
# entries: 75
#
# Total Return: btc_close    0.132070
# eth_close    0.134301
# Name: total_return, dtype: float64
#
# Order Records:
#     Order Id     Column                 Timestamp       Size       Price  \
# 0          0  btc_close 2020-07-25 00:00:00+00:00   1.030970   9699.6000
# 1          1  btc_close 2020-09-04 00:00:00+00:00   1.030970  10516.5000
# 2          2  btc_close 2020-12-17 00:00:00+00:00   0.442180  22805.7000
# 3          3  btc_close 2021-01-22 00:00:00+00:00   0.442180  31304.7900
# 4          4  btc_close 2021-02-06 00:00:00+00:00   0.266868  39195.5000
# 5          5  btc_close 2021-02-23 00:00:00+00:00   0.266868  48116.9700
# 6          6  btc_close 2021-03-11 00:00:00+00:00   0.185149  57781.1000
# 7          7  btc_close 2021-03-25 00:00:00+00:00   0.185149  52002.9900
# 8          8  btc_close 2021-10-05 00:00:00+00:00   0.205804  51462.3000
# 9          9  btc_close 2021-11-19 00:00:00+00:00   0.205804  57032.3700
# 10        10  btc_close 2023-12-04 00:00:00+00:00   0.254990  41985.1000
# 11        11  btc_close 2024-01-23 00:00:00+00:00   0.254990  39885.0300
# 12        12  btc_close 2024-02-05 00:00:00+00:00   0.249431  42706.1000
# 13        13  btc_close 2024-03-20 00:00:00+00:00   0.249431  61727.4000
# 14        14  btc_close 2024-11-11 00:00:00+00:00   0.125531  88637.1000
# 15        15  eth_close 2020-07-23 00:00:00+00:00  36.321371    275.3200
# 16        16  eth_close 2020-10-27 00:00:00+00:00  36.321371    382.7265
# 17        17  eth_close 2020-11-17 00:00:00+00:00  21.546868    482.2100
# 18        18  eth_close 2020-11-27 00:00:00+00:00  21.546868    486.9000
# 19        19  eth_close 2020-11-30 00:00:00+00:00  16.870877    616.4600
# 20        20  eth_close 2020-12-02 00:00:00+00:00  16.870877    554.8140
# 21        21  eth_close 2020-12-28 00:00:00+00:00  14.096299    730.4200
# 22        22  eth_close 2021-01-22 00:00:00+00:00  14.096299   1111.4460
# 23        23  eth_close 2021-02-04 00:00:00+00:00   6.788946   1595.7300
# 24        24  eth_close 2021-02-23 00:00:00+00:00   6.788946   1664.8650
# 25        25  eth_close 2021-03-13 00:00:00+00:00   5.661465   1921.8100
# 26        26  eth_close 2021-03-14 00:00:00+00:00   5.661465   1729.6290
# 27        27  eth_close 2021-04-05 00:00:00+00:00   5.112613   2106.8400
# 28        28  eth_close 2021-04-19 00:00:00+00:00   5.112613   2067.1740
# 29        29  eth_close 2021-05-01 00:00:00+00:00   3.650221   2945.3500
# 30        30  eth_close 2021-05-18 00:00:00+00:00   3.650221   3268.3320
# 31        31  eth_close 2021-10-05 00:00:00+00:00   3.092048   3515.1700
# 32        32  eth_close 2021-11-19 00:00:00+00:00   3.092048   4056.3720
# 33        33  eth_close 2023-12-10 00:00:00+00:00   4.692373   2351.9900
# 34        34  eth_close 2024-01-04 00:00:00+00:00   4.692373   2116.7910
# 35        35  eth_close 2024-02-07 00:00:00+00:00   4.505402   2425.1000
# 36        36  eth_close 2024-03-20 00:00:00+00:00   4.505402   3350.5560
#
#     Fees  Side
# 0    0.0   Buy
# 1    0.0  Sell
# 2    0.0   Buy
# 3    0.0  Sell
# 4    0.0   Buy
# 5    0.0  Sell
# 6    0.0   Buy
# 7    0.0  Sell
# 8    0.0   Buy
# 9    0.0  Sell
# 10   0.0   Buy
# 11   0.0  Sell
# 12   0.0   Buy
# 13   0.0  Sell
# 14   0.0   Buy
# 15   0.0   Buy
# 16   0.0  Sell
# 17   0.0   Buy
# 18   0.0  Sell
# 19   0.0   Buy
# 20   0.0  Sell
# 21   0.0   Buy
# 22   0.0  Sell
# 23   0.0   Buy
# 24   0.0  Sell
# 25   0.0   Buy
# 26   0.0  Sell
# 27   0.0   Buy
# 28   0.0  Sell
# 29   0.0   Buy
# 30   0.0  Sell
# 31   0.0   Buy
# 32   0.0  Sell
# 33   0.0   Buy
# 34   0.0  Sell
# 35   0.0   Buy
# 36   0.0  Sell

# %%
check = pf.orders.records_readable.sort_values(by='Timestamp')
check
# print total return
pf.total_return()
# Out:
# btc_close    0.132070
# eth_close    0.134301
# Name: total_return, dtype: float64
